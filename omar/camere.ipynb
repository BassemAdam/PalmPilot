# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier  # MLP is an NN
from sklearn import svm
import numpy as np
import argparse
import imutils  # If you are unable to install this library, ask the TA; we only need this in extract_hsv_histogram.
import cv2
import os
import random
import time
from commonfunctions import *
# Depending on library versions on your system, one of the following imports 
from sklearn.model_selection import train_test_split

# %%
import cv2
import numpy as np

def create_hand_mask_expanded(image):
    """Create a binary mask using YCrCb and LAB color spaces."""
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    ycrcb = cv2.cvtColor(blurred, cv2.COLOR_BGR2YCrCb)
    lab = cv2.cvtColor(blurred, cv2.COLOR_BGR2LAB)

    # Define thresholds for skin detection
    lower_ycrcb = np.array([0, 140, 100], dtype=np.uint8)
    upper_ycrcb = np.array([255, 180, 140], dtype=np.uint8)
    lower_lab = np.array([20, 135, 125], dtype=np.uint8)
    upper_lab = np.array([255, 175, 145], dtype=np.uint8)

    # Create masks for YCrCb and LAB
    mask_ycrcb = cv2.inRange(ycrcb, lower_ycrcb, upper_ycrcb)
    mask_lab = cv2.inRange(lab, lower_lab, upper_lab)
    combined_mask = cv2.bitwise_or(mask_ycrcb, mask_lab)

    # Clean the mask with morphological operations
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, ( 10,10))
    combined_mask = cv2.morphologyEx(combined_mask, cv2.MORPH_OPEN, kernel)
    combined_mask = cv2.morphologyEx(combined_mask, cv2.MORPH_CLOSE, kernel)
    #combined_mask = cv2.dilate(combined_mask, kernel, iterations=3)
    return combined_mask.astype(np.uint8)

def find_hand_contours(skin_mask, image):
    """Find the largest contour and compute its convex hull."""
    contours, _ = cv2.findContours(skin_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter out small contours
    contours = [cnt for cnt in contours if cv2.contourArea(cnt) > 3000]
    if not contours:
        return image, None, None

    # Sort contours by area
    contours = sorted(contours, key=cv2.contourArea, reverse=True)
    hand_contour = contours[0]
    # Visualize the convex hull
    output_image = image.copy()
    try:
        hull = cv2.convexHull(hand_contour)
        cv2.drawContours(output_image, [hull], -1, (255, 0, 0), 2)
    except Exception as e:
        print(f"Error processing contour: {e}")
        return output_image, None, None

    return output_image, hand_contour, hull

def create_color_mask(new_screen, hull, square_size=64):
    """
    Create a mask based on LAB color similarity within a bounding box using adaptive thresholding.
    """
    # Find the bounding box of the hull
    x, y, w, h = cv2.boundingRect(hull)

    # Calculate the center and create an inner box
    center_x, center_y = x + w // 2, y + h // 2
    inner_x, inner_y = center_x - square_size // 2, center_y - square_size // 2
    inner_x, inner_y = max(0, inner_x), max(0, inner_y)
    inner_w, inner_h = square_size, square_size


    # Convert to LAB color space
    lab_screen = cv2.cvtColor(new_screen, cv2.COLOR_BGR2LAB)

    # Extract inner box region and compute mean LAB color
    inner_box_region = lab_screen[inner_y:inner_y + inner_h, inner_x:inner_x + inner_w]
    avg_lab_color = cv2.mean(inner_box_region)[:3]

    # Apply LAB color thresholding to the bounding box
    bounding_box_region = lab_screen[y:y + h, x:x + w]
    diff = cv2.absdiff(bounding_box_region, np.uint8(avg_lab_color))
    diff_norm = np.linalg.norm(diff, axis=2).astype(np.uint8)

    # Apply adaptive thresholding to create a binary mask
    binary_mask = cv2.adaptiveThreshold(diff_norm, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                        cv2.THRESH_BINARY, 11, 2)
    
    lower_lab = np.array([20, 135, 125], dtype=np.uint8)
    upper_lab = np.array([255, 175, 145], dtype=np.uint8)
    mask_lab = cv2.inRange(bounding_box_region, lower_lab, upper_lab)
    final_mask = cv2.bitwise_and(binary_mask, mask_lab)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, ( 10,10))
    final_mask = cv2.morphologyEx(final_mask, cv2.MORPH_CLOSE, kernel)
    final_mask=resize_with_aspect_ratio(final_mask, target_size=(400, 400), pad_color=0)
    return final_mask

def resize_with_aspect_ratio(image, target_size=(300, 300), pad_color=0):
    h, w = image.shape[:2]
    target_w, target_h = target_size
    scale = min(target_w / w, target_h / h)
    new_w, new_h = int(w * scale), int(h * scale)
    if w == 0 or h == 0:
        print("Invalid bounding box dimensions:", w, h)
        return None
    resized_image = cv2.resize(image, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
    canvas = np.full((target_h, target_w), pad_color, dtype=np.uint8)
    x_offset = (target_w - new_w) // 2
    y_offset = (target_h - new_h) // 2
    canvas[y_offset:y_offset + new_h, x_offset:x_offset + new_w] = resized_image
    return canvas


def process_frame(frame):
    """Process the input frame to detect the hand region."""
    skin_mask = create_hand_mask_expanded(frame)
    output_image, hand_contour, hull = find_hand_contours(skin_mask, frame)

    
    

    if hull is not None:
        hull_points = np.squeeze(hull)
        cx = np.mean(hull_points[:, 0]).astype(int)  # Average x-coordinates
        cy = np.mean(hull_points[:, 1]).astype(int)  # Average y-coordinates
        print(f"Convex Hull Center: ({cx}, {cy})")
        hand_region = create_color_mask(frame, hull)
    else:
        hand_region = np.zeros_like(frame)

    return skin_mask, output_image, hand_region

def main():
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        skin_mask, output_image, hand_region = process_frame(frame)

        # Display results
        cv2.imshow("Original", frame)
        cv2.imshow("Skin Mask", skin_mask)
        cv2.imshow("Hand Detection", output_image)
        cv2.imshow("Hand Region (Box)", hand_region)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Convex Hull Center: (320, 335)
# Convex Hull Center: (317, 322)
# Convex Hull Center: (314, 328)
# Convex Hull Center: (317, 327)
# Convex Hull Center: (314, 326)
# Convex Hull Center: (303, 322)
# Convex Hull Center: (304, 330)
# Convex Hull Center: (299, 332)
# Convex Hull Center: (289, 319)
# Convex Hull Center: (290, 324)
# Convex Hull Center: (282, 332)
# Convex Hull Center: (281, 340)
# Convex Hull Center: (269, 326)
# Convex Hull Center: (267, 339)
# Convex Hull Center: (267, 343)
# Convex Hull Center: (254, 338)
# Convex Hull Center: (254, 329)
# Convex Hull Center: (256, 349)
# Convex Hull Center: (253, 343)
# Convex Hull Center: (240, 346)
# Convex Hull Center: (238, 359)
# Convex Hull Center: (227, 344)
# Convex Hull Center: (529, 375)
# Convex Hull Center: (546, 354)
# Convex Hull Center: (541, 382)
# Convex Hull Center: (528, 353)
# Convex Hull Center: (509, 335)
# Convex Hull Center: (506, 328)
# Convex Hull Center: (504, 326)
# Convex Hull Center: (519, 308)
# Convex Hull Center: (514, 313)
# Convex Hull Center: (517, 303)
# Convex Hull Center: (522, 306)
# Convex Hull Center: (524, 316)
# Convex Hull Center: (523, 321)
# Convex Hull Center: (531, 326)
# Convex Hull Center: (245, 335)
# Convex Hull Center: (248, 342)
# Convex Hull Center: (249, 342)
# Convex Hull Center: (258, 329)
# Convex Hull Center: (259, 340)
# Convex Hull Center: (255, 342)
# Convex Hull Center: (252, 337)
# Convex Hull Center: (255, 344)
# Convex Hull Center: (253, 335)
# Convex Hull Center: (259, 341)
# Convex Hull Center: (250, 335)
# Convex Hull Center: (255, 350)
# Convex Hull Center: (252, 340)
# Convex Hull Center: (253, 336)
# Convex Hull Center: (254, 346)
# Convex Hull Center: (254, 332)
# Convex Hull Center: (254, 340)
# Convex Hull Center: (263, 338)
# Convex Hull Center: (253, 344)
# Convex Hull Center: (253, 343)
# Convex Hull Center: (249, 341)
# Convex Hull Center: (252, 337)
# Convex Hull Center: (251, 335)
# Convex Hull Center: (259, 346)
# Convex Hull Center: (252, 334)
# Convex Hull Center: (249, 338)
# Convex Hull Center: (259, 342)
# Convex Hull Center: (264, 331)
# Convex Hull Center: (251, 335)
# Convex Hull Center: (254, 337)
# Convex Hull Center: (259, 336)
# Convex Hull Center: (256, 334)
# Convex Hull Center: (255, 328)
# Convex Hull Center: (255, 336)
# Convex Hull Center: (555, 296)
# Convex Hull Center: (553, 297)
# Convex Hull Center: (545, 294)
# Convex Hull Center: (551, 301)
# Convex Hull Center: (527, 294)
# Convex Hull Center: (533, 299)
# Convex Hull Center: (527, 292)
# Convex Hull Center: (525, 305)
# Convex Hull Center: (512, 302)
# Convex Hull Center: (508, 307)
# Convex Hull Center: (516, 305)
# Convex Hull Center: (510, 313)
# Convex Hull Center: (504, 304)
# Convex Hull Center: (507, 316)
# Convex Hull Center: (505, 306)
# Convex Hull Center: (507, 304)
# Convex Hull Center: (500, 314)
# Convex Hull Center: (494, 314)
# Convex Hull Center: (491, 313)
# Convex Hull Center: (491, 312)
# Convex Hull Center: (487, 317)
# Convex Hull Center: (475, 308)
# Convex Hull Center: (479, 316)
# Convex Hull Center: (473, 316)
# Convex Hull Center: (481, 322)
# Convex Hull Center: (480, 324)
# Convex Hull Center: (482, 319)
# Convex Hull Center: (479, 322)
# Convex Hull Center: (476, 313)
# Convex Hull Center: (476, 315)
# Convex Hull Center: (481, 320)
# Convex Hull Center: (475, 319)
# Convex Hull Center: (483, 315)
# Convex Hull Center: (480, 315)
# Convex Hull Center: (482, 316)
# Convex Hull Center: (479, 324)
# Convex Hull Center: (484, 329)
# Convex Hull Center: (495, 326)
# Convex Hull Center: (492, 329)
# Convex Hull Center: (488, 329)
# Convex Hull Center: (493, 319)
# Convex Hull Center: (498, 320)
# Convex Hull Center: (500, 328)
# Convex Hull Center: (499, 333)
# Convex Hull Center: (506, 339)
# Convex Hull Center: (518, 333)
# Convex Hull Center: (500, 316)
# Convex Hull Center: (501, 326)
# Convex Hull Center: (501, 324)
# Convex Hull Center: (499, 337)
# Convex Hull Center: (494, 332)
# Convex Hull Center: (495, 345)
# Convex Hull Center: (491, 340)
# Convex Hull Center: (488, 331)
# Convex Hull Center: (484, 338)
# Convex Hull Center: (491, 344)
# Convex Hull Center: (492, 342)
# Convex Hull Center: (491, 342)
# Convex Hull Center: (491, 332)
# Convex Hull Center: (497, 332)
# Convex Hull Center: (492, 341)
# Convex Hull Center: (486, 340)
# Convex Hull Center: (489, 324)
# Convex Hull Center: (489, 327)
# Convex Hull Center: (486, 347)
# Convex Hull Center: (487, 324)
# Convex Hull Center: (484, 331)
# Convex Hull Center: (491, 333)
# Convex Hull Center: (495, 335)
# Convex Hull Center: (496, 337)
# Convex Hull Center: (493, 329)
# Convex Hull Center: (490, 336)
# Convex Hull Center: (493, 320)
# Convex Hull Center: (493, 334)
# Convex Hull Center: (497, 328)
# Convex Hull Center: (501, 327)
# Convex Hull Center: (494, 307)
# Convex Hull Center: (485, 333)
# Convex Hull Center: (491, 338)
# Convex Hull Center: (485, 324)
# Convex Hull Center: (492, 333)
# Convex Hull Center: (488, 320)
# Convex Hull Center: (486, 325)
# Convex Hull Center: (492, 333)
# Convex Hull Center: (486, 340)
# Convex Hull Center: (489, 325)
# Convex Hull Center: (482, 332)
# Convex Hull Center: (478, 324)
# Convex Hull Center: (485, 332)
# Convex Hull Center: (475, 339)
# Convex Hull Center: (486, 340)
# Convex Hull Center: (489, 324)
# Convex Hull Center: (501, 343)
# Convex Hull Center: (498, 336)
# Convex Hull Center: (506, 332)
# Convex Hull Center: (498, 343)
# Convex Hull Center: (500, 332)
# Convex Hull Center: (503, 339)
# Convex Hull Center: (505, 346)
# Convex Hull Center: (499, 346)
# Convex Hull Center: (494, 330)
# Convex Hull Center: (501, 344)
# Convex Hull Center: (498, 345)
# Convex Hull Center: (497, 337)
# Convex Hull Center: (498, 333)
# Convex Hull Center: (494, 344)
# Convex Hull Center: (498, 335)
# Convex Hull Center: (498, 328)
# Convex Hull Center: (495, 330)
# Convex Hull Center: (487, 344)
# Convex Hull Center: (496, 332)
# Convex Hull Center: (485, 351)
# Convex Hull Center: (492, 335)
# Convex Hull Center: (495, 335)
# Convex Hull Center: (483, 337)
# Convex Hull Center: (489, 327)
# Convex Hull Center: (501, 331)
# Convex Hull Center: (489, 327)
# Convex Hull Center: (491, 325)
# Convex Hull Center: (496, 337)
# Convex Hull Center: (488, 336)
# Convex Hull Center: (495, 334)
# Convex Hull Center: (488, 339)
# Convex Hull Center: (498, 321)
# Convex Hull Center: (484, 330)
# Convex Hull Center: (498, 320)
# Convex Hull Center: (501, 330)
# Convex Hull Center: (494, 341)
# Convex Hull Center: (494, 328)
# Convex Hull Center: (498, 333)
# Convex Hull Center: (492, 347)
# Convex Hull Center: (490, 343)
# Convex Hull Center: (483, 347)
# Convex Hull Center: (500, 331)
# Convex Hull Center: (499, 348)
# Convex Hull Center: (495, 356)
# Convex Hull Center: (501, 340)
# Convex Hull Center: (498, 354)
# Convex Hull Center: (506, 351)
# Convex Hull Center: (501, 348)
# Convex Hull Center: (498, 357)
# Convex Hull Center: (496, 348)
# Convex Hull Center: (504, 348)
# Convex Hull Center: (502, 331)
# Convex Hull Center: (500, 346)
# Convex Hull Center: (503, 352)
# Convex Hull Center: (492, 340)
# Convex Hull Center: (506, 344)
# Convex Hull Center: (492, 343)
# Convex Hull Center: (486, 345)
# Convex Hull Center: (483, 355)
# Convex Hull Center: (488, 350)
# Convex Hull Center: (493, 356)
# Convex Hull Center: (493, 347)
# Convex Hull Center: (498, 354)
# Convex Hull Center: (479, 347)
# Convex Hull Center: (487, 344)
# Convex Hull Center: (490, 339)
# Convex Hull Center: (500, 346)
# Convex Hull Center: (497, 338)
# Convex Hull Center: (492, 348)
# Convex Hull Center: (491, 329)
# Convex Hull Center: (497, 345)
# Convex Hull Center: (484, 344)
# Convex Hull Center: (480, 350)
# Convex Hull Center: (469, 347)
# Convex Hull Center: (464, 349)
# Convex Hull Center: (469, 351)
# Convex Hull Center: (476, 351)
# Convex Hull Center: (467, 351)
# Convex Hull Center: (467, 339)
# Convex Hull Center: (466, 346)
# Convex Hull Center: (472, 350)
# Convex Hull Center: (476, 358)
# Convex Hull Center: (478, 367)
# Convex Hull Center: (479, 353)
# Convex Hull Center: (482, 364)
# Convex Hull Center: (485, 347)
# Convex Hull Center: (487, 355)
# Convex Hull Center: (485, 358)
# Convex Hull Center: (484, 352)
# Convex Hull Center: (249, 332)
# Convex Hull Center: (254, 334)
# Convex Hull Center: (251, 340)
# Convex Hull Center: (485, 352)
# Convex Hull Center: (475, 354)
# Convex Hull Center: (256, 342)
# Convex Hull Center: (249, 332)
# Convex Hull Center: (253, 330)
# Convex Hull Center: (481, 351)
# Convex Hull Center: (488, 350)
# Convex Hull Center: (482, 345)
# Convex Hull Center: (485, 346)
# Convex Hull Center: (483, 332)
# Convex Hull Center: (494, 328)
# Convex Hull Center: (487, 338)
# Convex Hull Center: (482, 335)
# Convex Hull Center: (480, 332)
# Convex Hull Center: (480, 345)
# Convex Hull Center: (480, 345)
# Convex Hull Center: (491, 334)
# Convex Hull Center: (482, 330)
# Convex Hull Center: (471, 330)
# Convex Hull Center: (481, 319)
# Convex Hull Center: (487, 331)
# Convex Hull Center: (468, 329)
# Convex Hull Center: (482, 329)
# Convex Hull Center: (475, 316)
# Convex Hull Center: (476, 326)
# Convex Hull Center: (479, 317)
# Convex Hull Center: (473, 317)
# Convex Hull Center: (473, 317)
# Convex Hull Center: (475, 303)
# Convex Hull Center: (481, 312)
# Convex Hull Center: (477, 311)
# Convex Hull Center: (483, 316)
# Convex Hull Center: (476, 307)
# Convex Hull Center: (486, 313)
# Convex Hull Center: (484, 316)
# Convex Hull Center: (481, 318)
# Convex Hull Center: (481, 314)
# Convex Hull Center: (481, 304)
# Convex Hull Center: (474, 312)
# Convex Hull Center: (474, 312)
# Convex Hull Center: (477, 307)
# Convex Hull Center: (479, 309)
# Convex Hull Center: (477, 314)
# Convex Hull Center: (477, 306)
# Convex Hull Center: (475, 311)
# Convex Hull Center: (476, 313)
# Convex Hull Center: (478, 305)
# Convex Hull Center: (480, 309)
# Convex Hull Center: (485, 307)
# Convex Hull Center: (476, 302)
# Convex Hull Center: (488, 300)
# Convex Hull Center: (488, 300)
# Convex Hull Center: (475, 294)
# Convex Hull Center: (480, 308)
# Convex Hull Center: (478, 297)
# Convex Hull Center: (488, 290)
# Convex Hull Center: (472, 298)
# Convex Hull Center: (486, 307)
# Convex Hull Center: (482, 298)
# Convex Hull Center: (483, 305)
# Convex Hull Center: (481, 295)
# Convex Hull Center: (480, 308)
# Convex Hull Center: (484, 307)
# Convex Hull Center: (484, 307)
# Convex Hull Center: (480, 316)
# Convex Hull Center: (479, 301)
# Convex Hull Center: (473, 306)
# Convex Hull Center: (487, 287)
# Convex Hull Center: (478, 301)
# Convex Hull Center: (480, 309)
# Convex Hull Center: (477, 306)
# Convex Hull Center: (474, 301)
# Convex Hull Center: (483, 306)
# Convex Hull Center: (475, 301)
# Convex Hull Center: (475, 294)
# Convex Hull Center: (475, 294)
# Convex Hull Center: (478, 296)
# Convex Hull Center: (480, 300)
# Convex Hull Center: (470, 309)
# Convex Hull Center: (472, 315)
# Convex Hull Center: (478, 307)
# Convex Hull Center: (483, 298)
# Convex Hull Center: (476, 298)
# Convex Hull Center: (484, 310)
# Convex Hull Center: (481, 309)
# Convex Hull Center: (474, 307)
# Convex Hull Center: (486, 300)
# Convex Hull Center: (486, 300)
# Convex Hull Center: (486, 313)
# Convex Hull Center: (476, 305)
# Convex Hull Center: (478, 305)
# Convex Hull Center: (484, 303)
# Convex Hull Center: (485, 300)
# Convex Hull Center: (479, 299)
# Convex Hull Center: (472, 310)
# Convex Hull Center: (470, 299)
# Convex Hull Center: (486, 299)
# Convex Hull Center: (480, 300)
# Convex Hull Center: (480, 305)
# Convex Hull Center: (480, 305)
# Convex Hull Center: (476, 311)
# Convex Hull Center: (477, 298)
# Convex Hull Center: (473, 314)
# Convex Hull Center: (464, 318)
# Convex Hull Center: (485, 298)
# Convex Hull Center: (469, 299)
# Convex Hull Center: (477, 309)
# Convex Hull Center: (477, 311)
# Convex Hull Center: (481, 315)
# Convex Hull Center: (471, 313)
# Convex Hull Center: (475, 320)
# Convex Hull Center: (467, 317)
# Convex Hull Center: (467, 317)
# Convex Hull Center: (469, 311)
# Convex Hull Center: (469, 320)
# Convex Hull Center: (474, 314)
# Convex Hull Center: (469, 319)
# Convex Hull Center: (468, 311)
# Convex Hull Center: (471, 319)
# Convex Hull Center: (468, 315)
# Convex Hull Center: (467, 315)
# Convex Hull Center: (464, 326)
# Convex Hull Center: (462, 326)
# Convex Hull Center: (464, 316)
# Convex Hull Center: (464, 316)
# Convex Hull Center: (461, 322)
# Convex Hull Center: (465, 316)
# Convex Hull Center: (470, 316)
# Convex Hull Center: (465, 320)
# Convex Hull Center: (464, 317)
# Convex Hull Center: (459, 330)
# Convex Hull Center: (460, 322)
# Convex Hull Center: (462, 325)
# Convex Hull Center: (461, 313)
# Convex Hull Center: (468, 320)
# Convex Hull Center: (466, 328)
# Convex Hull Center: (466, 328)
# Convex Hull Center: (466, 331)
# Convex Hull Center: (469, 326)
# Convex Hull Center: (467, 324)
# Convex Hull Center: (467, 329)
# Convex Hull Center: (474, 326)
# Convex Hull Center: (471, 324)
# Convex Hull Center: (471, 330)
# Convex Hull Center: (460, 331)
# Convex Hull Center: (468, 322)
# Convex Hull Center: (472, 320)
# Convex Hull Center: (468, 323)
# Convex Hull Center: (468, 323)
# Convex Hull Center: (472, 327)
# Convex Hull Center: (473, 324)
# Convex Hull Center: (474, 325)
# Convex Hull Center: (481, 324)
# Convex Hull Center: (473, 322)
# Convex Hull Center: (475, 325)
# Convex Hull Center: (466, 319)
# Convex Hull Center: (474, 316)
# Convex Hull Center: (469, 316)
# Convex Hull Center: (472, 323)
# Convex Hull Center: (477, 322)
# Convex Hull Center: (477, 322)
# Convex Hull Center: (477, 323)
# Convex Hull Center: (474, 323)
# Convex Hull Center: (479, 315)
# Convex Hull Center: (475, 310)
# Convex Hull Center: (475, 318)
# Convex Hull Center: (484, 315)
# Convex Hull Center: (484, 311)
# Convex Hull Center: (479, 316)
# Convex Hull Center: (486, 319)
# Convex Hull Center: (484, 319)
# Convex Hull Center: (481, 323)
# Convex Hull Center: (481, 323)
# Convex Hull Center: (487, 317)
# Convex Hull Center: (486, 318)
# Convex Hull Center: (481, 327)
# Convex Hull Center: (485, 328)
# Convex Hull Center: (491, 330)
# Convex Hull Center: (485, 326)
# Convex Hull Center: (493, 331)
# Convex Hull Center: (490, 335)
# Convex Hull Center: (487, 329)
# Convex Hull Center: (486, 336)
# Convex Hull Center: (485, 332)
# Convex Hull Center: (485, 332)
# Convex Hull Center: (506, 320)
# Convex Hull Center: (498, 326)
# Convex Hull Center: (500, 327)
# Convex Hull Center: (494, 323)
# Convex Hull Center: (496, 316)
# Convex Hull Center: (495, 323)
# Convex Hull Center: (490, 320)
# Convex Hull Center: (493, 315)
# Convex Hull Center: (502, 329)
# Convex Hull Center: (485, 319)
# Convex Hull Center: (483, 315)
# Convex Hull Center: (483, 315)
# Convex Hull Center: (480, 318)
# Convex Hull Center: (479, 319)
# Convex Hull Center: (480, 320)
# Convex Hull Center: (483, 316)
# Convex Hull Center: (481, 317)
# Convex Hull Center: (474, 314)
# Convex Hull Center: (477, 317)
# Convex Hull Center: (468, 328)
# Convex Hull Center: (477, 326)
# Convex Hull Center: (470, 329)
# Convex Hull Center: (466, 326)
# Convex Hull Center: (470, 326)
# Convex Hull Center: (470, 326)
# Convex Hull Center: (462, 333)
# Convex Hull Center: (459, 330)
# Convex Hull Center: (468, 321)
# Convex Hull Center: (466, 332)
# Convex Hull Center: (457, 320)
# Convex Hull Center: (468, 325)
# Convex Hull Center: (471, 330)
# Convex Hull Center: (472, 325)
# Convex Hull Center: (466, 321)
# Convex Hull Center: (468, 328)
# Convex Hull Center: (465, 325)
# Convex Hull Center: (465, 325)
# Convex Hull Center: (473, 323)
# Convex Hull Center: (462, 326)
# Convex Hull Center: (472, 335)
# Convex Hull Center: (468, 329)
# Convex Hull Center: (473, 324)
# Convex Hull Center: (468, 325)
# Convex Hull Center: (479, 338)
# Convex Hull Center: (480, 327)
# Convex Hull Center: (478, 335)
# Convex Hull Center: (467, 329)
# Convex Hull Center: (478, 327)
# Convex Hull Center: (478, 327)
# Convex Hull Center: (467, 318)
# Convex Hull Center: (472, 324)
# Convex Hull Center: (486, 323)
# Convex Hull Center: (483, 324)
# Convex Hull Center: (477, 322)
# Convex Hull Center: (477, 316)
# Convex Hull Center: (496, 317)
# Convex Hull Center: (486, 312)
# Convex Hull Center: (489, 321)
# Convex Hull Center: (496, 306)
# Convex Hull Center: (493, 322)
# Convex Hull Center: (493, 322)
# Convex Hull Center: (490, 316)
# Convex Hull Center: (488, 327)
# Convex Hull Center: (491, 321)
# Convex Hull Center: (483, 325)
# Convex Hull Center: (488, 312)
# Convex Hull Center: (484, 320)
# Convex Hull Center: (483, 319)
# Convex Hull Center: (490, 327)
# Convex Hull Center: (495, 317)
# Convex Hull Center: (493, 314)
# Convex Hull Center: (489, 318)
# Convex Hull Center: (489, 318)
# Convex Hull Center: (489, 319)
# Convex Hull Center: (492, 317)
# Convex Hull Center: (489, 312)
# Convex Hull Center: (489, 314)
# Convex Hull Center: (485, 310)
# Convex Hull Center: (486, 312)
# Convex Hull Center: (487, 311)
# Convex Hull Center: (481, 317)
# Convex Hull Center: (487, 316)
# Convex Hull Center: (487, 308)
# Convex Hull Center: (488, 310)
# Convex Hull Center: (488, 310)
# Convex Hull Center: (482, 310)
# Convex Hull Center: (484, 308)
# Convex Hull Center: (484, 314)
# Convex Hull Center: (484, 311)
# Convex Hull Center: (483, 318)
# Convex Hull Center: (487, 321)
# Convex Hull Center: (477, 299)
# Convex Hull Center: (481, 315)
# Convex Hull Center: (486, 315)
# Convex Hull Center: (495, 321)
# Convex Hull Center: (490, 326)
# Convex Hull Center: (490, 326)
# Convex Hull Center: (482, 329)
# Convex Hull Center: (493, 317)
# Convex Hull Center: (488, 317)
# Convex Hull Center: (480, 325)
# Convex Hull Center: (476, 322)
# Convex Hull Center: (480, 303)
# Convex Hull Center: (481, 320)
# Convex Hull Center: (487, 327)
# Convex Hull Center: (485, 320)
# Convex Hull Center: (485, 314)
# Convex Hull Center: (489, 321)
# Convex Hull Center: (489, 321)
# Convex Hull Center: (490, 319)
# Convex Hull Center: (491, 315)
# Convex Hull Center: (485, 319)
# Convex Hull Center: (497, 319)
# Convex Hull Center: (490, 317)
# Convex Hull Center: (485, 309)
# Convex Hull Center: (487, 322)
# Convex Hull Center: (481, 305)
# Convex Hull Center: (489, 319)
# Convex Hull Center: (492, 322)
# Convex Hull Center: (485, 297)
# Convex Hull Center: (504, 321)
# Convex Hull Center: (504, 321)
# Convex Hull Center: (496, 318)
# Convex Hull Center: (505, 335)
# Convex Hull Center: (495, 331)
# Convex Hull Center: (487, 341)
# Convex Hull Center: (494, 326)
# Convex Hull Center: (484, 333)
# Convex Hull Center: (496, 327)
# Convex Hull Center: (490, 326)
# Convex Hull Center: (482, 333)
# Convex Hull Center: (498, 335)
# Convex Hull Center: (494, 334)
# Convex Hull Center: (494, 334)
# Convex Hull Center: (483, 336)
# Convex Hull Center: (486, 329)
# Convex Hull Center: (487, 331)
# Convex Hull Center: (495, 333)
# Convex Hull Center: (493, 320)
# Convex Hull Center: (494, 332)
# Convex Hull Center: (489, 336)
# Convex Hull Center: (494, 335)
# Convex Hull Center: (490, 334)
# Convex Hull Center: (496, 341)
# Convex Hull Center: (497, 343)
# Convex Hull Center: (497, 343)
# Convex Hull Center: (497, 343)
# Convex Hull Center: (501, 335)
# Convex Hull Center: (493, 336)
# Convex Hull Center: (495, 328)
# Convex Hull Center: (498, 328)
# Convex Hull Center: (495, 326)
# Convex Hull Center: (495, 337)
# Convex Hull Center: (500, 346)
# Convex Hull Center: (494, 356)
# Convex Hull Center: (492, 337)
# Convex Hull Center: (494, 348)
# Convex Hull Center: (494, 348)
# Convex Hull Center: (498, 353)
# Convex Hull Center: (498, 359)
# Convex Hull Center: (489, 346)
# Convex Hull Center: (499, 351)
# Convex Hull Center: (496, 356)
# Convex Hull Center: (492, 352)
# Convex Hull Center: (492, 349)
# Convex Hull Center: (496, 357)
# Convex Hull Center: (494, 353)
# Convex Hull Center: (495, 362)
# Convex Hull Center: (490, 352)
# Convex Hull Center: (490, 352)
# Convex Hull Center: (495, 359)
# Convex Hull Center: (500, 350)
# Convex Hull Center: (500, 347)
# Convex Hull Center: (492, 353)
# Convex Hull Center: (496, 342)
# Convex Hull Center: (493, 354)
# Convex Hull Center: (497, 358)
# Convex Hull Center: (490, 355)
# Convex Hull Center: (498, 352)
# Convex Hull Center: (496, 359)
# Convex Hull Center: (496, 358)
# Convex Hull Center: (496, 358)
# Convex Hull Center: (489, 359)
# Convex Hull Center: (488, 356)
# Convex Hull Center: (494, 361)
# Convex Hull Center: (487, 359)
# Convex Hull Center: (492, 345)
# Convex Hull Center: (485, 354)
# Convex Hull Center: (485, 352)
# Convex Hull Center: (488, 347)
# Convex Hull Center: (484, 344)
# Convex Hull Center: (484, 344)
# Convex Hull Center: (485, 338)
# Convex Hull Center: (485, 338)
# Convex Hull Center: (487, 336)
# Convex Hull Center: (482, 345)
# Convex Hull Center: (488, 343)
# Convex Hull Center: (483, 341)
# Convex Hull Center: (486, 350)
# Convex Hull Center: (480, 335)
# Convex Hull Center: (483, 323)
# Convex Hull Center: (490, 324)
# Convex Hull Center: (496, 326)
# Convex Hull Center: (479, 329)
# Convex Hull Center: (483, 316)
# Convex Hull Center: (483, 316)
# Convex Hull Center: (479, 315)
# Convex Hull Center: (477, 314)
# Convex Hull Center: (481, 313)
# Convex Hull Center: (477, 309)
# Convex Hull Center: (476, 307)
# Convex Hull Center: (478, 312)
# Convex Hull Center: (476, 314)
# Convex Hull Center: (469, 313)
# Convex Hull Center: (472, 314)
# Convex Hull Center: (469, 313)
# Convex Hull Center: (471, 316)
# Convex Hull Center: (476, 312)
# Convex Hull Center: (476, 312)
# Convex Hull Center: (474, 312)
# Convex Hull Center: (481, 311)
# Convex Hull Center: (475, 306)
# Convex Hull Center: (484, 311)
# Convex Hull Center: (474, 317)
# Convex Hull Center: (483, 310)
# Convex Hull Center: (483, 307)
# Convex Hull Center: (482, 313)
# Convex Hull Center: (485, 307)
# Convex Hull Center: (484, 308)
# Convex Hull Center: (486, 317)
# Convex Hull Center: (486, 317)
# Convex Hull Center: (480, 308)
# Convex Hull Center: (478, 318)
# Convex Hull Center: (495, 320)
# Convex Hull Center: (494, 320)
# Convex Hull Center: (480, 319)
# Convex Hull Center: (485, 309)
# Convex Hull Center: (472, 324)
# Convex Hull Center: (477, 319)
# Convex Hull Center: (483, 312)
# Convex Hull Center: (475, 323)
# Convex Hull Center: (471, 309)
# Convex Hull Center: (471, 309)
# Convex Hull Center: (479, 328)
# Convex Hull Center: (474, 320)
# Convex Hull Center: (474, 319)
# Convex Hull Center: (468, 316)
# Convex Hull Center: (467, 312)
# Convex Hull Center: (473, 326)
# Convex Hull Center: (471, 309)
# Convex Hull Center: (470, 313)
# Convex Hull Center: (475, 319)
# Convex Hull Center: (480, 336)
# Convex Hull Center: (478, 323)
# Convex Hull Center: (478, 323)
# Convex Hull Center: (482, 329)
# Convex Hull Center: (476, 334)
# Convex Hull Center: (484, 338)
# Convex Hull Center: (471, 342)
# Convex Hull Center: (479, 335)
# Convex Hull Center: (477, 337)
# Convex Hull Center: (470, 344)
# Convex Hull Center: (473, 345)
# Convex Hull Center: (466, 360)
# Convex Hull Center: (470, 371)
# Convex Hull Center: (467, 359)
# Convex Hull Center: (467, 359)
# Convex Hull Center: (474, 352)
# Convex Hull Center: (478, 349)
# Convex Hull Center: (469, 355)
# Convex Hull Center: (467, 349)
# Convex Hull Center: (482, 341)
# Convex Hull Center: (474, 342)
# Convex Hull Center: (464, 354)
# Convex Hull Center: (471, 349)
# Convex Hull Center: (469, 345)
# Convex Hull Center: (457, 356)
# Convex Hull Center: (456, 354)
# Convex Hull Center: (456, 354)
# Convex Hull Center: (461, 359)
# Convex Hull Center: (464, 357)
# Convex Hull Center: (458, 352)
# Convex Hull Center: (474, 347)
# Convex Hull Center: (461, 352)
# Convex Hull Center: (461, 361)
# Convex Hull Center: (476, 356)
# Convex Hull Center: (458, 361)
# Convex Hull Center: (465, 351)
# Convex Hull Center: (468, 356)
# Convex Hull Center: (468, 357)
# Convex Hull Center: (468, 357)
# Convex Hull Center: (461, 364)
# Convex Hull Center: (462, 361)
# Convex Hull Center: (469, 358)
# Convex Hull Center: (456, 360)
# Convex Hull Center: (465, 354)
# Convex Hull Center: (470, 358)
# Convex Hull Center: (463, 352)
# Convex Hull Center: (452, 363)
# Convex Hull Center: (457, 363)
# Convex Hull Center: (461, 360)
# Convex Hull Center: (457, 361)
# Convex Hull Center: (457, 361)
# Convex Hull Center: (461, 360)
# Convex Hull Center: (463, 363)
# Convex Hull Center: (468, 357)
# Convex Hull Center: (459, 361)
# Convex Hull Center: (477, 358)
# Convex Hull Center: (473, 353)
# Convex Hull Center: (485, 349)
# Convex Hull Center: (484, 350)
# Convex Hull Center: (475, 354)
# Convex Hull Center: (481, 349)
# Convex Hull Center: (492, 346)
# Convex Hull Center: (479, 343)
# Convex Hull Center: (479, 343)
# Convex Hull Center: (473, 345)
# Convex Hull Center: (483, 340)
# Convex Hull Center: (464, 346)
# Convex Hull Center: (492, 339)
# Convex Hull Center: (488, 341)
# Convex Hull Center: (482, 349)
# Convex Hull Center: (460, 346)
# Convex Hull Center: (468, 343)
# Convex Hull Center: (472, 342)
# Convex Hull Center: (474, 337)
# Convex Hull Center: (468, 342)
# Convex Hull Center: (468, 342)
# Convex Hull Center: (492, 329)
# Convex Hull Center: (468, 340)
# Convex Hull Center: (467, 347)
# Convex Hull Center: (467, 340)
# Convex Hull Center: (465, 345)
# Convex Hull Center: (463, 337)
# Convex Hull Center: (473, 345)
# Convex Hull Center: (477, 337)
# Convex Hull Center: (473, 338)
# Convex Hull Center: (454, 347)
# Convex Hull Center: (466, 335)
# Convex Hull Center: (466, 335)
# Convex Hull Center: (471, 326)
# Convex Hull Center: (441, 329)
# Convex Hull Center: (444, 340)
# Convex Hull Center: (469, 335)
# Convex Hull Center: (453, 338)
# Convex Hull Center: (453, 335)
# Convex Hull Center: (462, 338)
# Convex Hull Center: (431, 337)
# Convex Hull Center: (432, 336)
# Convex Hull Center: (442, 326)
# Convex Hull Center: (453, 326)
# Convex Hull Center: (453, 326)
# Convex Hull Center: (455, 321)
# Convex Hull Center: (454, 320)
# Convex Hull Center: (463, 333)
# Convex Hull Center: (463, 328)
# Convex Hull Center: (466, 326)
# Convex Hull Center: (454, 337)
# Convex Hull Center: (441, 334)
# Convex Hull Center: (447, 324)
# Convex Hull Center: (457, 346)
# Convex Hull Center: (460, 339)
# Convex Hull Center: (452, 344)
# Convex Hull Center: (452, 344)
# Convex Hull Center: (445, 356)
# Convex Hull Center: (475, 336)
# Convex Hull Center: (470, 345)
# Convex Hull Center: (470, 332)
# Convex Hull Center: (470, 334)
# Convex Hull Center: (455, 341)
# Convex Hull Center: (451, 339)
# Convex Hull Center: (453, 335)
# Convex Hull Center: (459, 348)
# Convex Hull Center: (451, 351)
# Convex Hull Center: (462, 354)
# Convex Hull Center: (462, 354)
# Convex Hull Center: (459, 341)
# Convex Hull Center: (481, 325)
# Convex Hull Center: (462, 341)
# Convex Hull Center: (474, 323)
# Convex Hull Center: (465, 328)
# Convex Hull Center: (456, 318)
# Convex Hull Center: (462, 314)
# Convex Hull Center: (460, 307)
# Convex Hull Center: (470, 303)
# Convex Hull Center: (479, 306)
# Convex Hull Center: (492, 318)
# Convex Hull Center: (492, 318)
# Convex Hull Center: (477, 356)
# Convex Hull Center: (486, 405)
# Convex Hull Center: (268, 326)
# Convex Hull Center: (278, 331)
# Convex Hull Center: (280, 333)
# Convex Hull Center: (297, 333)
# Convex Hull Center: (309, 326)
# Convex Hull Center: (307, 327)
# Convex Hull Center: (315, 332)
# Convex Hull Center: (309, 334)
# Convex Hull Center: (322, 327)
# Convex Hull Center: (322, 327)
# Convex Hull Center: (328, 320)
# Convex Hull Center: (330, 336)
# Convex Hull Center: (337, 323)
# Convex Hull Center: (334, 315)
# Convex Hull Center: (347, 308)
# Convex Hull Center: (351, 323)
# Convex Hull Center: (349, 288)
# Convex Hull Center: (360, 307)
# Convex Hull Center: (359, 296)
# Convex Hull Center: (364, 302)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier  # MLP is an NN
from sklearn import svm
import numpy as np
import argparse
import imutils  # If you are unable to install this library, ask the TA; we only need this in extract_hsv_histogram.
import cv2
import os
import random
import time
from commonfunctions import *
# Depending on library versions on your system, one of the following imports 
from sklearn.model_selection import train_test_split

# %%
def eq_hist(img):
    # Step 1: Compute the histogram
    img= img.astype(int)
    h, _ = np.histogram(img, bins=256, range=(0, 256))
    
    # Step 2: Compute the cumulative distribution function (CDF)
    h_c = np.cumsum(h)
    
    # Step 3: Normalize the CDF to the range [0, 255]
    t = np.round(255 * h_c / h_c[-1]).astype(np.uint8)
    
    # Step 4: Map the original pixel values to equalized values
    equalized_img = t[img]
    
    return equalized_img



def gamma_correction(c,gamma,img):
    gamma_img = c*np.power(img,gamma)
    return gamma_img

# %%
def detect_hand(image):
    copy = image.copy()
    hsv = cv2.cvtColor(copy, cv2.COLOR_BGR2HSV)

    # Skin color range in HSV
    lower_skin = (0, 20, 70)
    upper_skin = (20, 255, 255)

    # Create mask
    mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Load face detector
    
    # Morphological operations to clean noise
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Filter by area and aspect ratio
        min_area = 5000
        filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

        if filtered_contours:
            hand_contour = max(filtered_contours, key=cv2.contourArea)

            # Convex Hull and Convexity Defects
            hull = cv2.convexHull(hand_contour, returnPoints=False)
            defects = cv2.convexityDefects(hand_contour, hull)

            # Draw the hand contour and convex hull
            cv2.drawContours(copy, [hand_contour], -1, (0, 255, 0), 2)
            cv2.drawContours(copy, [cv2.convexHull(hand_contour)], -1, (255, 0, 0), 2)

            # Highlight defects
            if defects is not None:
                for i in range(defects.shape[0]):
                    s, e, f, d = defects[i][0]
                    far = tuple(hand_contour[f][0])
                    cv2.circle(copy, far, 5, (0, 0, 255), -1)

    return copy

# %%
import cv2
import numpy as np

def detect_hand(image):
    copy = image.copy()
    hsv = cv2.cvtColor(copy, cv2.COLOR_BGR2HSV)

    # Skin color range in HSV
    lower_skin = (0, 20, 70)
    upper_skin = (20, 255, 255)

    # Create mask for skin color
    mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Morphological operations to clean noise
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    # Load the face detector (Haar Cascade Classifier)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Detect faces in the image
    gray = cv2.cvtColor(copy, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Initialize an empty image for the result
    result = np.zeros_like(image)

    # Find contours for hand detection
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Filter by area and aspect ratio
        min_area = 5000
        filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

        if filtered_contours:
            # Loop over the filtered contours and draw bounding boxes
            for contour in filtered_contours:
                # Get bounding rectangle for each contour
                x, y, w, h = cv2.boundingRect(contour)
                # Create a mask for the current rectangle
                hand_mask = np.zeros_like(image)
                cv2.drawContours(hand_mask, [contour], -1, (255, 255, 255), thickness=cv2.FILLED)

                # Apply the hand mask to the original image
                temp_result = cv2.bitwise_and(image, hand_mask)

                # Copy the result to ensure the hand areas are preserved
                result = cv2.add(result, temp_result)

    # Now mask out the face regions by adding black rectangles in the result
    for (x, y, w, h) in faces:
        cv2.rectangle(result, (x, y), (x + w, y + h), (0, 0, 0), -1)

    return result

# %%
def highlight_skin_with_two_largest(image):
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define skin color range in HSV
    lower_skin = (0, 20, 70)
    upper_skin = (20, 255, 255)

    # Create a mask for skin regions
    mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Find contours in the mask
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter and sort contours by area
    contours = [cnt for cnt in contours if cv2.contourArea(cnt) > 3000]
    contours = sorted(contours, key=cv2.contourArea, reverse=True)

    # Create a copy of the original image to color the selected regions
    result = image.copy()

    if len(contours) >= 2:
        # Color the largest contour blue
        cv2.drawContours(result, [contours[0]], -1, (255, 0, 0), -1)  # Blue for the largest
        
        # Color the second largest contour red
        cv2.drawContours(result, [contours[1]], -1, (0, 0, 255), -1)  # Red for the second largest
    elif len(contours) == 1:
        # Split the largest contour into two along its bounding box
        x, y, w, h = cv2.boundingRect(contours[0])
        mid_x = x + w // 2

        # Split the mask of the largest contour
        contour_mask = np.zeros_like(mask)
        cv2.drawContours(contour_mask, [contours[0]], -1, 255, -1)
        left_half = contour_mask[:, :mid_x]
        right_half = contour_mask[:, mid_x:]

        # Color the left half blue
        result[:, :mid_x][left_half > 0] = (255, 0, 0)  # Blue
        
        # Color the right half red
        result[:, mid_x:][right_half > 0] = (0, 0, 255)  # Red

    return result

def detect_hand_using_fingers(image):
    copy = image.copy()
    hsv = cv2.cvtColor(copy, cv2.COLOR_BGR2HSV)

    # Skin color range in HSV
    lower_skin = (0, 20, 70)
    upper_skin = (20, 255, 255)

    # Create mask for skin color
    mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Morphological operations to clean noise
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    # Find contours for hand detection
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Filter by area and aspect ratio
        min_area = 5000
        filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

        if filtered_contours:
            # Get the largest contour (assumed to be the hand)
            hand_contour = max(filtered_contours, key=cv2.contourArea)

            # Approximate the contour to make it simpler (remove small jaggedness)
            epsilon = 0.02 * cv2.arcLength(hand_contour, True)
            approx_contour = cv2.approxPolyDP(hand_contour, epsilon, True)

            # Get convex hull and convexity defects to detect fingers
            hull = cv2.convexHull(approx_contour, returnPoints=False)

            # Ensure the convex hull is valid
            if len(hull) > 3:  # At least 4 points needed for convexity defects
                defects = cv2.convexityDefects(hand_contour, hull)

                # Draw convex hull
                cv2.drawContours(copy, [cv2.convexHull(hand_contour)], -1, (0, 255, 0), 2)

                if defects is not None:
                    # Loop through defects to find finger tips
                    finger_tips = []
                    for i in range(defects.shape[0]):
                        s, e, f, d = defects[i][0]
                        far = tuple(hand_contour[f][0])
                        finger_tips.append(far)

                        # Draw the finger tips
                        cv2.circle(copy, far, 5, (0, 0, 255), -1)

                    # If there are finger tips, use them to define the hand region
                    if finger_tips:
                        # Use finger tips to estimate the upper region of the hand
                        # Find the top-most point among finger tips
                        finger_tips.sort(key=lambda x: x[1])  # Sort by y-coordinate (topmost first)
                        top_finger = finger_tips[0]  # This is the top-most finger tip

                        # Assuming the hand's region is above this finger
                        x, y, w, h = cv2.boundingRect(hand_contour)
                        extended_y = max(y - 50, 0)  # Extend upwards from the palm
                        cv2.rectangle(copy, (x, extended_y), (x + w, y + h), (0, 255, 255), 2)

    return copy

# %%
def highlight_thin_skin(image):
    # Convert the image to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define skin color range in HSV
    lower_skin = (0, 20, 70)
    upper_skin = (20, 255, 255)

    # Create a mask for skin regions
    mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Find contours in the mask
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create a copy of the original image to color the selected regions
    result = image.copy()

    # Iterate over each contour to check aspect ratio dynamically
    for contour in contours:
        if cv2.contourArea(contour)>1000 and cv2.contourArea(contour)<10000:  # Filter small contours
            # Fit a minimum area rotated rectangle around the contour
            rect = cv2.minAreaRect(contour)
            box = cv2.boxPoints(rect)  # Get the 4 points of the rectangle
            box = np.int0(box)  # Convert to integer
            #print(contour)
            # Calculate the width and height of the rectangle
            width = rect[1][0]
            height = rect[1][1]

            # Ensure width is always smaller than height

            # Calculate the aspect ratio (length / width)
            aspect_ratio =  width/height if width > 0 else 0
            
            print(aspect_ratio)
            # Check if the aspect ratio matches the desired threshold
            if 0.5 <= aspect_ratio <= 0.9:  # Adjust the range if necessary
                # Draw the contour or rectangle on the result image
                cv2.drawContours(result, [box], -1, (0, 255, 0), 2)  # Green rectangle
                cv2.drawContours(result, [contour], -1, (0, 255, 0), -1)  # Fill the contour with green

    return result

# %%
import cv2
import numpy as np

def detect_hand_with_enhancements(image):
    # Step 1: Preprocessing (Blur to reduce noise)
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)

    # Step 2: Dynamic Skin-Tone Detection
    lower_skin = np.array([0, 30, 60], dtype=np.uint8)
    upper_skin = np.array([20, 150, 255], dtype=np.uint8)
    skin_mask = cv2.inRange(hsv, lower_skin, upper_skin)

    # Step 3: Adaptive Edge Detection
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.equalizeHist(gray)  # Enhance contrast
    edges = cv2.Canny(gray, 100, 200)

    # Ensure edges are connected
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
    #edges = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)

    # Step 4: Contour Detection on Skin Mask
    contours, _ = cv2.findContours(skin_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    filled_mask = np.zeros_like(edges)

    # Create a mask with additional padding for floodFill
    flood_fill_mask = np.zeros((edges.shape[0] + 2, edges.shape[1] + 2), dtype=np.uint8)
    flood_fill_mask[1:-1, 1:-1] = edges
    # Overlay for displaying centroids
    centroid_overlay = image.copy()

    # Skin tone mean for comparison
    skin_tone_mean = np.array([10, 100, 150])  # Mean skin tone in HSV
    threshold = 25  # Acceptable difference threshold

    for contour in contours:
        # Filter small contours
        if cv2.contourArea(contour) > 3000:
            # Calculate the centroid of the contour
            M = cv2.moments(contour)
            if M["m00"] != 0:  # Avoid division by zero
                x = int(M["m10"] / M["m00"])
                y = int(M["m01"] / M["m00"])

                # Draw the centroid point on the overlay
                cv2.circle(centroid_overlay, (x, y), 5, (0, 0, 255), -1)  # Red circle for centroid

                # Calculate the average color inside the contour
                mask = np.zeros(image.shape[:2], dtype=np.uint8)
                cv2.drawContours(mask, [contour], -1, 255, -1)  # Create a mask of the contour
                mean_color = cv2.mean(hsv, mask=mask)[:3]

                # Check if the mean color is within the threshold
                if np.all(np.abs(np.array(mean_color) - skin_tone_mean) < threshold):
                    # Flood-fill the region using the modified flood-fill mask
                    cv2.floodFill(filled_mask, flood_fill_mask, seedPoint=(x, y), newVal=255)

    # Step 5: Morphological Operations (Post-Processing)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    filled_mask = cv2.morphologyEx(filled_mask, cv2.MORPH_CLOSE, kernel)  # Close small gaps
    filled_mask = cv2.morphologyEx(filled_mask, cv2.MORPH_OPEN, kernel)   # Remove noise

    # Combine the filled regions with the original image
    result = cv2.bitwise_and(image, image, mask=filled_mask)

    return result, filled_mask, edges, centroid_overlay

# %%
def process_segments(image):
    # Convert the image to HSV and YCrCb color spaces
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    hsv = cv2.cvtColor(blurred, cv2.COLOR_BGR2HSV)
    ycrcb = cv2.cvtColor(blurred, cv2.COLOR_BGR2YCrCb)
    
    # Optimized thresholds for skin detection
    lower_hsv = np.array([0, 30, 60], dtype=np.uint8)
    upper_hsv = np.array([20, 150, 255], dtype=np.uint8)
    lower_ycrcb = np.array([0, 135, 85], dtype=np.uint8)
    upper_ycrcb = np.array([255, 180, 135], dtype=np.uint8)
    
    mask_hsv = cv2.inRange(hsv, lower_hsv, upper_hsv)
    mask_ycrcb = cv2.inRange(ycrcb, lower_ycrcb, upper_ycrcb)
    
    # Combine masks with weights
    combined_mask = cv2.addWeighted(mask_hsv, 0.5, mask_ycrcb, 0.5, 0)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    skin_mask = cv2.morphologyEx(combined_mask, cv2.MORPH_OPEN, kernel)
    skin_mask = cv2.morphologyEx(skin_mask, cv2.MORPH_CLOSE, kernel)
    
    # Find contours in the mask
    contours, _ = cv2.findContours(skin_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = [cnt for cnt in contours if cv2.contourArea(cnt) > 3000]
    contours = sorted(contours, key=cv2.contourArea, reverse=True)

    segmented_image = image.copy()

    if len(contours) >= 2:
        largest = contours[0]
        second_largest = contours[1]
    elif len(contours) == 1:
        x, y, w, h = cv2.boundingRect(contours[0])
        top_half = contours[0][contours[0][:, 0, 1] < y + h // 2]
        bottom_half = contours[0][contours[0][:, 0, 1] >= y + h // 2]
        if top_half.shape[0] > 0 and bottom_half.shape[0] > 0:
            largest = top_half
            second_largest = bottom_half
        else:
            return image, None, None, None
    else:
        return image, None, None, None

    # Debugging: Print contour shapes
    print(f"Largest Contour: {largest.shape}")
    print(f"Second Largest Contour: {second_largest.shape}")

    # Draw red and blue regions on the segmented image
    if len(largest) > 0:
        cv2.drawContours(segmented_image, [largest], -1, (255, 0, 0), -1)  # Blue for the largest
    if len(second_largest) > 0:
        cv2.drawContours(segmented_image, [second_largest], -1, (0, 0, 255), -1)  # Red for the second largest

    def resize_with_aspect_ratio(image, target_size=(300, 300), pad_color=0):
        h, w = image.shape[:2]
        target_w, target_h = target_size
        scale = min(target_w / w, target_h / h)
        new_w, new_h = int(w * scale), int(h * scale)
        resized_image = cv2.resize(image, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
        canvas = np.full((target_h, target_w), pad_color, dtype=np.uint8)
        x_offset = (target_w - new_w) // 2
        y_offset = (target_h - new_h) // 2
        canvas[y_offset:y_offset + new_h, x_offset:x_offset + new_w] = resized_image
        return canvas

    def create_segment(contour, target_size=(300, 300)):
        if contour is None or len(contour) == 0:
            return None
        mask = np.zeros_like(image[:, :, 0])
        cv2.drawContours(mask, [contour], -1, 255, -1)
        x, y, w, h = cv2.boundingRect(contour)
        cropped = mask[y:y + h, x:x + w]
        return resize_with_aspect_ratio(cropped, target_size)

    blue_segment = create_segment(largest)
    red_segment = create_segment(second_largest)

    return image, segmented_image, blue_segment, red_segment

def main():
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.flip(frame, 1)
        original, segmented, blue_part, red_part = process_segments(frame)

        if original is not None:
            cv2.imshow("Original Image", cv2.resize(original, (600, 400)))
        if segmented is not None:
            cv2.imshow("Red and Blue Screen", cv2.resize(segmented, (600, 400)))
        if blue_part is not None:
            cv2.imshow("Blue Part", blue_part)
        if red_part is not None:
            cv2.imshow("Red Part", red_part)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (160, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (143, 1, 2)
# Second Largest Contour: (183, 1, 2)
# Largest Contour: (146, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (161, 1, 2)
# Second Largest Contour: (120, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (162, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (141, 1, 2)
# Second Largest Contour: (120, 1, 2)
# Largest Contour: (164, 1, 2)
# Second Largest Contour: (115, 1, 2)
# Largest Contour: (148, 1, 2)
# Second Largest Contour: (105, 1, 2)
# Largest Contour: (148, 1, 2)
# Second Largest Contour: (105, 1, 2)
# Largest Contour: (154, 1, 2)
# Second Largest Contour: (114, 1, 2)
# Largest Contour: (149, 1, 2)
# Second Largest Contour: (111, 1, 2)
# Largest Contour: (138, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (151, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (145, 1, 2)
# Second Largest Contour: (117, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (107, 1, 2)
# Largest Contour: (160, 1, 2)
# Second Largest Contour: (110, 1, 2)
# Largest Contour: (158, 1, 2)
# Second Largest Contour: (119, 1, 2)
# Largest Contour: (158, 1, 2)
# Second Largest Contour: (119, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (119, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (133, 1, 2)
# Second Largest Contour: (110, 1, 2)
# Largest Contour: (143, 1, 2)
# Second Largest Contour: (107, 1, 2)
# Largest Contour: (161, 1, 2)
# Second Largest Contour: (112, 1, 2)
# Largest Contour: (242, 1, 2)
# Second Largest Contour: (170, 1, 2)
# Largest Contour: (252, 1, 2)
# Second Largest Contour: (140, 1, 2)
# Largest Contour: (236, 1, 2)
# Second Largest Contour: (188, 1, 2)
# Largest Contour: (236, 1, 2)
# Second Largest Contour: (188, 1, 2)
# Largest Contour: (240, 1, 2)
# Second Largest Contour: (166, 1, 2)
# Largest Contour: (263, 1, 2)
# Second Largest Contour: (138, 1, 2)
# Largest Contour: (235, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (250, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (257, 1, 2)
# Second Largest Contour: (190, 1, 2)
# Largest Contour: (246, 1, 2)
# Second Largest Contour: (198, 1, 2)
# Largest Contour: (255, 1, 2)
# Second Largest Contour: (223, 1, 2)
# Largest Contour: (483, 1, 2)
# Second Largest Contour: (187, 1, 2)
# Largest Contour: (483, 1, 2)
# Second Largest Contour: (187, 1, 2)
# Largest Contour: (503, 1, 2)
# Second Largest Contour: (172, 1, 2)
# Largest Contour: (469, 1, 2)
# Second Largest Contour: (240, 1, 2)
# Largest Contour: (230, 1, 2)
# Second Largest Contour: (456, 1, 2)
# Largest Contour: (257, 1, 2)
# Second Largest Contour: (483, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (475, 1, 2)
# Largest Contour: (434, 1, 2)
# Second Largest Contour: (464, 1, 2)
# Largest Contour: (360, 1, 2)
# Second Largest Contour: (464, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (432, 1, 2)
# Largest Contour: (321, 1, 2)
# Second Largest Contour: (438, 1, 2)
# Largest Contour: (297, 1, 2)
# Second Largest Contour: (379, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (290, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (287, 1, 2)
# Largest Contour: (286, 1, 2)
# Second Largest Contour: (425, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (341, 1, 2)
# Largest Contour: (428, 1, 2)
# Second Largest Contour: (322, 1, 2)
# Largest Contour: (437, 1, 2)
# Second Largest Contour: (336, 1, 2)
# Largest Contour: (430, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (532, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (543, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (572, 1, 2)
# Second Largest Contour: (345, 1, 2)
# Largest Contour: (558, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (579, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (573, 1, 2)
# Second Largest Contour: (346, 1, 2)
# Largest Contour: (560, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (552, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (507, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (537, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (559, 1, 2)
# Second Largest Contour: (326, 1, 2)
# Largest Contour: (493, 1, 2)
# Second Largest Contour: (336, 1, 2)
# Largest Contour: (521, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (505, 1, 2)
# Second Largest Contour: (340, 1, 2)
# Largest Contour: (523, 1, 2)
# Second Largest Contour: (363, 1, 2)
# Largest Contour: (545, 1, 2)
# Second Largest Contour: (417, 1, 2)
# Largest Contour: (519, 1, 2)
# Second Largest Contour: (344, 1, 2)
# Largest Contour: (550, 1, 2)
# Second Largest Contour: (333, 1, 2)
# Largest Contour: (503, 1, 2)
# Second Largest Contour: (359, 1, 2)
# Largest Contour: (524, 1, 2)
# Second Largest Contour: (434, 1, 2)
# Largest Contour: (552, 1, 2)
# Second Largest Contour: (423, 1, 2)
# Largest Contour: (500, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (522, 1, 2)
# Second Largest Contour: (329, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (493, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (462, 1, 2)
# Largest Contour: (344, 1, 2)
# Second Largest Contour: (456, 1, 2)
# Largest Contour: (431, 1, 2)
# Second Largest Contour: (441, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (399, 1, 2)
# Largest Contour: (320, 1, 2)
# Second Largest Contour: (361, 1, 2)
# Largest Contour: (430, 1, 2)
# Second Largest Contour: (373, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (384, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (370, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (368, 1, 2)
# Largest Contour: (351, 1, 2)
# Second Largest Contour: (388, 1, 2)
# Largest Contour: (374, 1, 2)
# Second Largest Contour: (411, 1, 2)
# Largest Contour: (374, 1, 2)
# Second Largest Contour: (411, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (383, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (396, 1, 2)
# Largest Contour: (325, 1, 2)
# Second Largest Contour: (431, 1, 2)
# Largest Contour: (347, 1, 2)
# Second Largest Contour: (383, 1, 2)
# Largest Contour: (374, 1, 2)
# Second Largest Contour: (385, 1, 2)
# Largest Contour: (364, 1, 2)
# Second Largest Contour: (396, 1, 2)
# Largest Contour: (370, 1, 2)
# Second Largest Contour: (400, 1, 2)
# Largest Contour: (370, 1, 2)
# Second Largest Contour: (400, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (365, 1, 2)
# Second Largest Contour: (366, 1, 2)
# Largest Contour: (359, 1, 2)
# Second Largest Contour: (375, 1, 2)
# Largest Contour: (386, 1, 2)
# Second Largest Contour: (354, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (373, 1, 2)
# Largest Contour: (331, 1, 2)
# Second Largest Contour: (354, 1, 2)
# Largest Contour: (354, 1, 2)
# Second Largest Contour: (347, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (366, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (367, 1, 2)
# Second Largest Contour: (355, 1, 2)
# Largest Contour: (372, 1, 2)
# Second Largest Contour: (369, 1, 2)
# Largest Contour: (352, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (361, 1, 2)
# Second Largest Contour: (352, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (369, 1, 2)
# Second Largest Contour: (343, 1, 2)
# Largest Contour: (306, 1, 2)
# Second Largest Contour: (353, 1, 2)
# Largest Contour: (318, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (318, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (304, 1, 2)
# Second Largest Contour: (342, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (344, 1, 2)
# Largest Contour: (364, 1, 2)
# Second Largest Contour: (362, 1, 2)
# Largest Contour: (354, 1, 2)
# Second Largest Contour: (363, 1, 2)
# Largest Contour: (387, 1, 2)
# Second Largest Contour: (346, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (356, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (345, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (366, 1, 2)
# Largest Contour: (342, 1, 2)
# Second Largest Contour: (357, 1, 2)
# Largest Contour: (350, 1, 2)
# Second Largest Contour: (340, 1, 2)
# Largest Contour: (355, 1, 2)
# Second Largest Contour: (375, 1, 2)
# Largest Contour: (373, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (362, 1, 2)
# Second Largest Contour: (351, 1, 2)
# Largest Contour: (351, 1, 2)
# Second Largest Contour: (390, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (404, 1, 2)
# Largest Contour: (404, 1, 2)
# Second Largest Contour: (342, 1, 2)
# Largest Contour: (450, 1, 2)
# Second Largest Contour: (341, 1, 2)
# Largest Contour: (416, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (459, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (498, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (480, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (509, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (533, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (551, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (560, 1, 2)
# Second Largest Contour: (277, 1, 2)
# Largest Contour: (528, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (526, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (516, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (523, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (517, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (528, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (542, 1, 2)
# Second Largest Contour: (315, 1, 2)
# Largest Contour: (464, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (468, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (444, 1, 2)
# Second Largest Contour: (299, 1, 2)
# Largest Contour: (456, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (413, 1, 2)
# Second Largest Contour: (306, 1, 2)
# Largest Contour: (439, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (458, 1, 2)
# Second Largest Contour: (312, 1, 2)
# Largest Contour: (488, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (511, 1, 2)
# Second Largest Contour: (298, 1, 2)
# Largest Contour: (516, 1, 2)
# Second Largest Contour: (303, 1, 2)
# Largest Contour: (552, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (600, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (554, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (589, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (575, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (555, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (504, 1, 2)
# Second Largest Contour: (339, 1, 2)
# Largest Contour: (495, 1, 2)
# Second Largest Contour: (322, 1, 2)
# Largest Contour: (457, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (449, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (449, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (451, 1, 2)
# Second Largest Contour: (348, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (394, 1, 2)
# Largest Contour: (352, 1, 2)
# Second Largest Contour: (362, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (351, 1, 2)
# Largest Contour: (357, 1, 2)
# Second Largest Contour: (352, 1, 2)
# Largest Contour: (343, 1, 2)
# Second Largest Contour: (379, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (360, 1, 2)
# Largest Contour: (339, 1, 2)
# Second Largest Contour: (348, 1, 2)
# Largest Contour: (339, 1, 2)
# Second Largest Contour: (348, 1, 2)
# Largest Contour: (445, 1, 2)
# Second Largest Contour: (372, 1, 2)
# Largest Contour: (371, 1, 2)
# Second Largest Contour: (418, 1, 2)
# Largest Contour: (387, 1, 2)
# Second Largest Contour: (336, 1, 2)
# Largest Contour: (423, 1, 2)
# Second Largest Contour: (345, 1, 2)
# Largest Contour: (418, 1, 2)
# Second Largest Contour: (395, 1, 2)
# Largest Contour: (436, 1, 2)
# Second Largest Contour: (394, 1, 2)
# Largest Contour: (453, 1, 2)
# Second Largest Contour: (345, 1, 2)
# Largest Contour: (485, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (485, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (493, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (479, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (519, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (505, 1, 2)
# Second Largest Contour: (332, 1, 2)
# Largest Contour: (535, 1, 2)
# Second Largest Contour: (332, 1, 2)
# Largest Contour: (511, 1, 2)
# Second Largest Contour: (296, 1, 2)
# Largest Contour: (528, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (565, 1, 2)
# Second Largest Contour: (296, 1, 2)
# Largest Contour: (565, 1, 2)
# Second Largest Contour: (296, 1, 2)
# Largest Contour: (591, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (599, 1, 2)
# Second Largest Contour: (298, 1, 2)
# Largest Contour: (595, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (632, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (687, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (678, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (655, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (655, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (638, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (686, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (699, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (710, 1, 2)
# Second Largest Contour: (297, 1, 2)
# Largest Contour: (700, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (631, 1, 2)
# Second Largest Contour: (412, 1, 2)
# Largest Contour: (685, 1, 2)
# Second Largest Contour: (329, 1, 2)
# Largest Contour: (730, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (668, 1, 2)
# Second Largest Contour: (329, 1, 2)
# Largest Contour: (698, 1, 2)
# Second Largest Contour: (346, 1, 2)
# Largest Contour: (676, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (611, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (618, 1, 2)
# Second Largest Contour: (408, 1, 2)
# Largest Contour: (590, 1, 2)
# Second Largest Contour: (425, 1, 2)
# Largest Contour: (604, 1, 2)
# Second Largest Contour: (391, 1, 2)
# Largest Contour: (591, 1, 2)
# Second Largest Contour: (443, 1, 2)
# Largest Contour: (556, 1, 2)
# Second Largest Contour: (411, 1, 2)
# Largest Contour: (528, 1, 2)
# Second Largest Contour: (428, 1, 2)
# Largest Contour: (525, 1, 2)
# Second Largest Contour: (455, 1, 2)
# Largest Contour: (544, 1, 2)
# Second Largest Contour: (446, 1, 2)
# Largest Contour: (492, 1, 2)
# Second Largest Contour: (438, 1, 2)
# Largest Contour: (503, 1, 2)
# Second Largest Contour: (410, 1, 2)
# Largest Contour: (479, 1, 2)
# Second Largest Contour: (422, 1, 2)
# Largest Contour: (437, 1, 2)
# Second Largest Contour: (422, 1, 2)
# Largest Contour: (447, 1, 2)
# Second Largest Contour: (426, 1, 2)
# Largest Contour: (405, 1, 2)
# Second Largest Contour: (397, 1, 2)
# Largest Contour: (390, 1, 2)
# Second Largest Contour: (421, 1, 2)
# Largest Contour: (392, 1, 2)
# Second Largest Contour: (428, 1, 2)
# Largest Contour: (402, 1, 2)
# Second Largest Contour: (421, 1, 2)
# Largest Contour: (379, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (432, 1, 2)
# Second Largest Contour: (400, 1, 2)
# Largest Contour: (404, 1, 2)
# Second Largest Contour: (378, 1, 2)
# Largest Contour: (419, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (433, 1, 2)
# Second Largest Contour: (361, 1, 2)
# Largest Contour: (411, 1, 2)
# Second Largest Contour: (365, 1, 2)
# Largest Contour: (388, 1, 2)
# Second Largest Contour: (360, 1, 2)
# Largest Contour: (467, 1, 2)
# Second Largest Contour: (364, 1, 2)
# Largest Contour: (432, 1, 2)
# Second Largest Contour: (353, 1, 2)
# Largest Contour: (445, 1, 2)
# Second Largest Contour: (358, 1, 2)
# Largest Contour: (435, 1, 2)
# Second Largest Contour: (337, 1, 2)
# Largest Contour: (439, 1, 2)
# Second Largest Contour: (336, 1, 2)
# Largest Contour: (520, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (513, 1, 2)
# Second Largest Contour: (343, 1, 2)
# Largest Contour: (494, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (504, 1, 2)
# Second Largest Contour: (357, 1, 2)
# Largest Contour: (481, 1, 2)
# Second Largest Contour: (355, 1, 2)
# Largest Contour: (491, 1, 2)
# Second Largest Contour: (359, 1, 2)
# Largest Contour: (491, 1, 2)
# Second Largest Contour: (359, 1, 2)
# Largest Contour: (378, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (456, 1, 2)
# Second Largest Contour: (340, 1, 2)
# Largest Contour: (449, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (373, 1, 2)
# Second Largest Contour: (356, 1, 2)
# Largest Contour: (390, 1, 2)
# Second Largest Contour: (376, 1, 2)
# Largest Contour: (399, 1, 2)
# Second Largest Contour: (380, 1, 2)
# Largest Contour: (403, 1, 2)
# Second Largest Contour: (414, 1, 2)
# Largest Contour: (448, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (448, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (350, 1, 2)
# Second Largest Contour: (367, 1, 2)
# Largest Contour: (343, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (341, 1, 2)
# Second Largest Contour: (349, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (359, 1, 2)
# Largest Contour: (364, 1, 2)
# Second Largest Contour: (368, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (412, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (406, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (407, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (407, 1, 2)
# Largest Contour: (409, 1, 2)
# Second Largest Contour: (439, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (423, 1, 2)
# Largest Contour: (402, 1, 2)
# Second Largest Contour: (417, 1, 2)
# Largest Contour: (342, 1, 2)
# Second Largest Contour: (429, 1, 2)
# Largest Contour: (448, 1, 2)
# Second Largest Contour: (333, 1, 2)
# Largest Contour: (409, 1, 2)
# Second Largest Contour: (329, 1, 2)
# Largest Contour: (443, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (423, 1, 2)
# Second Largest Contour: (341, 1, 2)
# Largest Contour: (457, 1, 2)
# Second Largest Contour: (332, 1, 2)
# Largest Contour: (449, 1, 2)
# Second Largest Contour: (341, 1, 2)
# Largest Contour: (427, 1, 2)
# Second Largest Contour: (406, 1, 2)
# Largest Contour: (451, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (468, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (462, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (452, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (487, 1, 2)
# Second Largest Contour: (342, 1, 2)
# Largest Contour: (470, 1, 2)
# Second Largest Contour: (446, 1, 2)
# Largest Contour: (463, 1, 2)
# Second Largest Contour: (428, 1, 2)
# Largest Contour: (476, 1, 2)
# Second Largest Contour: (416, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (507, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (516, 1, 2)
# Second Largest Contour: (400, 1, 2)
# Largest Contour: (508, 1, 2)
# Second Largest Contour: (391, 1, 2)
# Largest Contour: (520, 1, 2)
# Second Largest Contour: (405, 1, 2)
# Largest Contour: (544, 1, 2)
# Second Largest Contour: (402, 1, 2)
# Largest Contour: (523, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (577, 1, 2)
# Second Largest Contour: (348, 1, 2)
# Largest Contour: (547, 1, 2)
# Second Largest Contour: (325, 1, 2)
# Largest Contour: (569, 1, 2)
# Second Largest Contour: (409, 1, 2)
# Largest Contour: (546, 1, 2)
# Second Largest Contour: (397, 1, 2)
# Largest Contour: (556, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (578, 1, 2)
# Second Largest Contour: (426, 1, 2)
# Largest Contour: (586, 1, 2)
# Second Largest Contour: (450, 1, 2)
# Largest Contour: (572, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (578, 1, 2)
# Second Largest Contour: (357, 1, 2)
# Largest Contour: (606, 1, 2)
# Second Largest Contour: (441, 1, 2)
# Largest Contour: (575, 1, 2)
# Second Largest Contour: (342, 1, 2)
# Largest Contour: (565, 1, 2)
# Second Largest Contour: (363, 1, 2)
# Largest Contour: (610, 1, 2)
# Second Largest Contour: (354, 1, 2)
# Largest Contour: (595, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (604, 1, 2)
# Second Largest Contour: (339, 1, 2)
# Largest Contour: (588, 1, 2)
# Second Largest Contour: (427, 1, 2)
# Largest Contour: (565, 1, 2)
# Second Largest Contour: (438, 1, 2)
# Largest Contour: (556, 1, 2)
# Second Largest Contour: (340, 1, 2)
# Largest Contour: (545, 1, 2)
# Second Largest Contour: (434, 1, 2)
# Largest Contour: (540, 1, 2)
# Second Largest Contour: (347, 1, 2)
# Largest Contour: (524, 1, 2)
# Second Largest Contour: (408, 1, 2)
# Largest Contour: (523, 1, 2)
# Second Largest Contour: (415, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (416, 1, 2)
# Largest Contour: (522, 1, 2)
# Second Largest Contour: (326, 1, 2)
# Largest Contour: (525, 1, 2)
# Second Largest Contour: (404, 1, 2)
# Largest Contour: (472, 1, 2)
# Second Largest Contour: (387, 1, 2)
# Largest Contour: (458, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (489, 1, 2)
# Second Largest Contour: (349, 1, 2)
# Largest Contour: (460, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (460, 1, 2)
# Second Largest Contour: (350, 1, 2)
# Largest Contour: (441, 1, 2)
# Second Largest Contour: (418, 1, 2)
# Largest Contour: (341, 1, 2)
# Second Largest Contour: (443, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (423, 1, 2)
# Largest Contour: (325, 1, 2)
# Second Largest Contour: (435, 1, 2)
# Largest Contour: (362, 1, 2)
# Second Largest Contour: (386, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (380, 1, 2)
# Largest Contour: (350, 1, 2)
# Second Largest Contour: (389, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (382, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (382, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (341, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (325, 1, 2)
# Largest Contour: (348, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (363, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (447, 1, 2)
# Second Largest Contour: (305, 1, 2)
# Largest Contour: (367, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (431, 1, 2)
# Second Largest Contour: (315, 1, 2)
# Largest Contour: (391, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (391, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (369, 1, 2)
# Second Largest Contour: (312, 1, 2)
# Largest Contour: (384, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (355, 1, 2)
# Second Largest Contour: (299, 1, 2)
# Largest Contour: (369, 1, 2)
# Second Largest Contour: (297, 1, 2)
# Largest Contour: (380, 1, 2)
# Second Largest Contour: (276, 1, 2)
# Largest Contour: (358, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (382, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (351, 1, 2)
# Second Largest Contour: (280, 1, 2)
# Largest Contour: (445, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (445, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (444, 1, 2)
# Second Largest Contour: (287, 1, 2)
# Largest Contour: (429, 1, 2)
# Second Largest Contour: (290, 1, 2)
# Largest Contour: (397, 1, 2)
# Second Largest Contour: (299, 1, 2)
# Largest Contour: (358, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (377, 1, 2)
# Second Largest Contour: (284, 1, 2)
# Largest Contour: (414, 1, 2)
# Second Largest Contour: (274, 1, 2)
# Largest Contour: (442, 1, 2)
# Second Largest Contour: (274, 1, 2)
# Largest Contour: (455, 1, 2)
# Second Largest Contour: (260, 1, 2)
# Largest Contour: (479, 1, 2)
# Second Largest Contour: (274, 1, 2)
# Largest Contour: (483, 1, 2)
# Second Largest Contour: (250, 1, 2)
# Largest Contour: (489, 1, 2)
# Second Largest Contour: (284, 1, 2)
# Largest Contour: (403, 1, 2)
# Second Largest Contour: (264, 1, 2)
# Largest Contour: (412, 1, 2)
# Second Largest Contour: (259, 1, 2)
# Largest Contour: (420, 1, 2)
# Second Largest Contour: (261, 1, 2)
# Largest Contour: (522, 1, 2)
# Second Largest Contour: (248, 1, 2)
# Largest Contour: (499, 1, 2)
# Second Largest Contour: (221, 1, 2)
# Largest Contour: (383, 1, 2)
# Second Largest Contour: (230, 1, 2)
# Largest Contour: (383, 1, 2)
# Second Largest Contour: (256, 1, 2)
# Largest Contour: (493, 1, 2)
# Second Largest Contour: (236, 1, 2)
# Largest Contour: (416, 1, 2)
# Second Largest Contour: (244, 1, 2)
# Largest Contour: (459, 1, 2)
# Second Largest Contour: (248, 1, 2)
# Largest Contour: (465, 1, 2)
# Second Largest Contour: (250, 1, 2)
# Largest Contour: (383, 1, 2)
# Second Largest Contour: (240, 1, 2)
# Largest Contour: (395, 1, 2)
# Second Largest Contour: (258, 1, 2)
# Largest Contour: (404, 1, 2)
# Second Largest Contour: (255, 1, 2)
# Largest Contour: (400, 1, 2)
# Second Largest Contour: (289, 1, 2)
# Largest Contour: (497, 1, 2)
# Second Largest Contour: (263, 1, 2)
# Largest Contour: (491, 1, 2)
# Second Largest Contour: (295, 1, 2)
# Largest Contour: (402, 1, 2)
# Second Largest Contour: (262, 1, 2)
# Largest Contour: (408, 1, 2)
# Second Largest Contour: (283, 1, 2)
# Largest Contour: (420, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (372, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (407, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (357, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (424, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (397, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (416, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (398, 1, 2)
# Second Largest Contour: (346, 1, 2)
# Largest Contour: (346, 1, 2)
# Second Largest Contour: (335, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (344, 1, 2)
# Second Largest Contour: (344, 1, 2)
# Largest Contour: (317, 1, 2)
# Second Largest Contour: (380, 1, 2)
# Largest Contour: (335, 1, 2)
# Second Largest Contour: (359, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (425, 1, 2)
# Largest Contour: (352, 1, 2)
# Second Largest Contour: (421, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (344, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (363, 1, 2)
# Largest Contour: (327, 1, 2)
# Second Largest Contour: (332, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (401, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (332, 1, 2)
# Largest Contour: (335, 1, 2)
# Second Largest Contour: (348, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (439, 1, 2)
# Largest Contour: (335, 1, 2)
# Second Largest Contour: (392, 1, 2)
# Largest Contour: (335, 1, 2)
# Second Largest Contour: (392, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (337, 1, 2)
# Largest Contour: (282, 1, 2)
# Second Largest Contour: (450, 1, 2)
# Largest Contour: (415, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (486, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (358, 1, 2)
# Second Largest Contour: (303, 1, 2)
# Largest Contour: (351, 1, 2)
# Second Largest Contour: (286, 1, 2)
# Largest Contour: (370, 1, 2)
# Second Largest Contour: (279, 1, 2)
# Largest Contour: (398, 1, 2)
# Second Largest Contour: (273, 1, 2)
# Largest Contour: (398, 1, 2)
# Second Largest Contour: (273, 1, 2)
# Largest Contour: (359, 1, 2)
# Second Largest Contour: (266, 1, 2)
# Largest Contour: (464, 1, 2)
# Second Largest Contour: (275, 1, 2)
# Largest Contour: (501, 1, 2)
# Second Largest Contour: (270, 1, 2)
# Largest Contour: (401, 1, 2)
# Second Largest Contour: (257, 1, 2)
# Largest Contour: (513, 1, 2)
# Second Largest Contour: (227, 1, 2)
# Largest Contour: (507, 1, 2)
# Second Largest Contour: (244, 1, 2)
# Largest Contour: (410, 1, 2)
# Second Largest Contour: (252, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (238, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (238, 1, 2)
# Largest Contour: (429, 1, 2)
# Second Largest Contour: (225, 1, 2)
# Largest Contour: (418, 1, 2)
# Second Largest Contour: (245, 1, 2)
# Largest Contour: (341, 1, 2)
# Second Largest Contour: (247, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (232, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (254, 1, 2)
# Largest Contour: (293, 1, 2)
# Second Largest Contour: (242, 1, 2)
# Largest Contour: (310, 1, 2)
# Second Largest Contour: (235, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (261, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (261, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (229, 1, 2)
# Largest Contour: (311, 1, 2)
# Second Largest Contour: (236, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (254, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (270, 1, 2)
# Largest Contour: (318, 1, 2)
# Second Largest Contour: (278, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (290, 1, 2)
# Largest Contour: (344, 1, 2)
# Second Largest Contour: (270, 1, 2)
# Largest Contour: (311, 1, 2)
# Second Largest Contour: (270, 1, 2)
# Largest Contour: (347, 1, 2)
# Second Largest Contour: (295, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (292, 1, 2)
# Largest Contour: (327, 1, 2)
# Second Largest Contour: (296, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (287, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (310, 1, 2)
# Second Largest Contour: (292, 1, 2)
# Largest Contour: (348, 1, 2)
# Second Largest Contour: (298, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (305, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (307, 1, 2)
# Second Largest Contour: (308, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (366, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (371, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (361, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (370, 1, 2)
# Second Largest Contour: (315, 1, 2)
# Largest Contour: (399, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (373, 1, 2)
# Second Largest Contour: (303, 1, 2)
# Largest Contour: (379, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (421, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (417, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (440, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (439, 1, 2)
# Second Largest Contour: (308, 1, 2)
# Largest Contour: (432, 1, 2)
# Second Largest Contour: (295, 1, 2)
# Largest Contour: (484, 1, 2)
# Second Largest Contour: (306, 1, 2)
# Largest Contour: (526, 1, 2)
# Second Largest Contour: (338, 1, 2)
# Largest Contour: (529, 1, 2)
# Second Largest Contour: (373, 1, 2)
# Largest Contour: (506, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (564, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (581, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (601, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (588, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (679, 1, 2)
# Second Largest Contour: (297, 1, 2)
# Largest Contour: (764, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (796, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (788, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (750, 1, 2)
# Second Largest Contour: (295, 1, 2)
# Largest Contour: (789, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (763, 1, 2)
# Second Largest Contour: (297, 1, 2)
# Largest Contour: (735, 1, 2)
# Second Largest Contour: (292, 1, 2)
# Largest Contour: (744, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (722, 1, 2)
# Second Largest Contour: (295, 1, 2)
# Largest Contour: (732, 1, 2)
# Second Largest Contour: (293, 1, 2)
# Largest Contour: (736, 1, 2)
# Second Largest Contour: (296, 1, 2)
# Largest Contour: (739, 1, 2)
# Second Largest Contour: (291, 1, 2)
# Largest Contour: (739, 1, 2)
# Second Largest Contour: (291, 1, 2)
# Largest Contour: (709, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (663, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (688, 1, 2)
# Second Largest Contour: (291, 1, 2)
# Largest Contour: (709, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (699, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (684, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (699, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (661, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (661, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (676, 1, 2)
# Second Largest Contour: (322, 1, 2)
# Largest Contour: (661, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (632, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (645, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (646, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (645, 1, 2)
# Second Largest Contour: (297, 1, 2)
# Largest Contour: (635, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (622, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (622, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (611, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (604, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (580, 1, 2)
# Second Largest Contour: (325, 1, 2)
# Largest Contour: (557, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (556, 1, 2)
# Second Largest Contour: (322, 1, 2)
# Largest Contour: (552, 1, 2)
# Second Largest Contour: (306, 1, 2)
# Largest Contour: (539, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (533, 1, 2)
# Second Largest Contour: (305, 1, 2)
# Largest Contour: (533, 1, 2)
# Second Largest Contour: (305, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (515, 1, 2)
# Largest Contour: (297, 1, 2)
# Second Largest Contour: (481, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (469, 1, 2)
# Largest Contour: (306, 1, 2)
# Second Largest Contour: (497, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (486, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (454, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (440, 1, 2)
# Largest Contour: (290, 1, 2)
# Second Largest Contour: (460, 1, 2)
# Largest Contour: (304, 1, 2)
# Second Largest Contour: (476, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (439, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (498, 1, 2)
# Largest Contour: (345, 1, 2)
# Second Largest Contour: (450, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (470, 1, 2)
# Largest Contour: (313, 1, 2)
# Second Largest Contour: (447, 1, 2)
# Largest Contour: (317, 1, 2)
# Second Largest Contour: (446, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (488, 1, 2)
# Largest Contour: (304, 1, 2)
# Second Largest Contour: (437, 1, 2)
# Largest Contour: (293, 1, 2)
# Second Largest Contour: (454, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (473, 1, 2)
# Largest Contour: (307, 1, 2)
# Second Largest Contour: (474, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (510, 1, 2)
# Largest Contour: (321, 1, 2)
# Second Largest Contour: (495, 1, 2)
# Largest Contour: (497, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (508, 1, 2)
# Second Largest Contour: (318, 1, 2)
# Largest Contour: (523, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (553, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (499, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (593, 1, 2)
# Second Largest Contour: (319, 1, 2)
# Largest Contour: (598, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (598, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (646, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (627, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (715, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (698, 1, 2)
# Second Largest Contour: (289, 1, 2)
# Largest Contour: (756, 1, 2)
# Second Largest Contour: (340, 1, 2)
# Largest Contour: (794, 1, 2)
# Second Largest Contour: (312, 1, 2)
# Largest Contour: (795, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (807, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (820, 1, 2)
# Second Largest Contour: (309, 1, 2)
# Largest Contour: (861, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (850, 1, 2)
# Second Largest Contour: (305, 1, 2)
# Largest Contour: (847, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (828, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (843, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (804, 1, 2)
# Second Largest Contour: (299, 1, 2)
# Largest Contour: (816, 1, 2)
# Second Largest Contour: (317, 1, 2)
# Largest Contour: (861, 1, 2)
# Second Largest Contour: (325, 1, 2)
# Largest Contour: (804, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (778, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (791, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (748, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (747, 1, 2)
# Second Largest Contour: (292, 1, 2)
# Largest Contour: (710, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (663, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (651, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (651, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (617, 1, 2)
# Second Largest Contour: (315, 1, 2)
# Largest Contour: (601, 1, 2)
# Second Largest Contour: (329, 1, 2)
# Largest Contour: (513, 1, 2)
# Second Largest Contour: (330, 1, 2)
# Largest Contour: (489, 1, 2)
# Second Largest Contour: (303, 1, 2)
# Largest Contour: (515, 1, 2)
# Second Largest Contour: (302, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (477, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (485, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (463, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (463, 1, 2)
# Largest Contour: (313, 1, 2)
# Second Largest Contour: (426, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (403, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (429, 1, 2)
# Largest Contour: (297, 1, 2)
# Second Largest Contour: (410, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (414, 1, 2)
# Largest Contour: (310, 1, 2)
# Second Largest Contour: (380, 1, 2)
# Largest Contour: (303, 1, 2)
# Second Largest Contour: (404, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (324, 1, 2)
# Second Largest Contour: (450, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (447, 1, 2)
# Largest Contour: (321, 1, 2)
# Second Largest Contour: (458, 1, 2)
# Largest Contour: (341, 1, 2)
# Second Largest Contour: (490, 1, 2)
# Largest Contour: (289, 1, 2)
# Second Largest Contour: (487, 1, 2)
# Largest Contour: (500, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (505, 1, 2)
# Second Largest Contour: (306, 1, 2)
# Largest Contour: (579, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (579, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (570, 1, 2)
# Second Largest Contour: (312, 1, 2)
# Largest Contour: (581, 1, 2)
# Second Largest Contour: (301, 1, 2)
# Largest Contour: (595, 1, 2)
# Second Largest Contour: (314, 1, 2)
# Largest Contour: (604, 1, 2)
# Second Largest Contour: (307, 1, 2)
# Largest Contour: (642, 1, 2)
# Second Largest Contour: (320, 1, 2)
# Largest Contour: (662, 1, 2)
# Second Largest Contour: (321, 1, 2)
# Largest Contour: (665, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (657, 1, 2)
# Second Largest Contour: (336, 1, 2)
# Largest Contour: (749, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (793, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (839, 1, 2)
# Second Largest Contour: (337, 1, 2)
# Largest Contour: (824, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (876, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (843, 1, 2)
# Second Largest Contour: (311, 1, 2)
# Largest Contour: (809, 1, 2)
# Second Largest Contour: (334, 1, 2)
# Largest Contour: (874, 1, 2)
# Second Largest Contour: (304, 1, 2)
# Largest Contour: (864, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (857, 1, 2)
# Second Largest Contour: (316, 1, 2)
# Largest Contour: (824, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (820, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (772, 1, 2)
# Second Largest Contour: (310, 1, 2)
# Largest Contour: (765, 1, 2)
# Second Largest Contour: (328, 1, 2)
# Largest Contour: (717, 1, 2)
# Second Largest Contour: (306, 1, 2)
# Largest Contour: (641, 1, 2)
# Second Largest Contour: (308, 1, 2)
# Largest Contour: (615, 1, 2)
# Second Largest Contour: (324, 1, 2)
# Largest Contour: (597, 1, 2)
# Second Largest Contour: (308, 1, 2)
# Largest Contour: (551, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (527, 1, 2)
# Second Largest Contour: (394, 1, 2)
# Largest Contour: (532, 1, 2)
# Second Largest Contour: (417, 1, 2)
# Largest Contour: (330, 1, 2)
# Second Largest Contour: (533, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (556, 1, 2)
# Largest Contour: (344, 1, 2)
# Second Largest Contour: (497, 1, 2)
# Largest Contour: (357, 1, 2)
# Second Largest Contour: (533, 1, 2)
# Largest Contour: (331, 1, 2)
# Second Largest Contour: (474, 1, 2)
# Largest Contour: (352, 1, 2)
# Second Largest Contour: (471, 1, 2)
# Largest Contour: (433, 1, 2)
# Second Largest Contour: (479, 1, 2)
# Largest Contour: (331, 1, 2)
# Second Largest Contour: (455, 1, 2)
# Largest Contour: (306, 1, 2)
# Second Largest Contour: (427, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (423, 1, 2)
# Largest Contour: (342, 1, 2)
# Second Largest Contour: (397, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (432, 1, 2)
# Largest Contour: (332, 1, 2)
# Second Largest Contour: (411, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (394, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (465, 1, 2)
# Largest Contour: (305, 1, 2)
# Second Largest Contour: (414, 1, 2)
# Largest Contour: (305, 1, 2)
# Second Largest Contour: (414, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (467, 1, 2)
# Largest Contour: (320, 1, 2)
# Second Largest Contour: (452, 1, 2)
# Largest Contour: (317, 1, 2)
# Second Largest Contour: (408, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (433, 1, 2)
# Largest Contour: (335, 1, 2)
# Second Largest Contour: (441, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (447, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (337, 1, 2)
# Second Largest Contour: (440, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (317, 1, 2)
# Second Largest Contour: (396, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (423, 1, 2)
# Largest Contour: (327, 1, 2)
# Second Largest Contour: (397, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (379, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (368, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (370, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (381, 1, 2)
# Largest Contour: (331, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (331, 1, 2)
# Second Largest Contour: (377, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (362, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (385, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (362, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (375, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (342, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (363, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (372, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (349, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (349, 1, 2)
# Largest Contour: (433, 1, 2)
# Second Largest Contour: (323, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (327, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (285, 1, 2)
# Largest Contour: (349, 1, 2)
# Second Largest Contour: (266, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (266, 1, 2)
# Largest Contour: (340, 1, 2)
# Second Largest Contour: (265, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (250, 1, 2)
# Largest Contour: (325, 1, 2)
# Second Largest Contour: (236, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (231, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (236, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (239, 1, 2)
# Largest Contour: (350, 1, 2)
# Second Largest Contour: (226, 1, 2)
# Largest Contour: (315, 1, 2)
# Second Largest Contour: (233, 1, 2)
# Largest Contour: (348, 1, 2)
# Second Largest Contour: (226, 1, 2)
# Largest Contour: (344, 1, 2)
# Second Largest Contour: (249, 1, 2)
# Largest Contour: (347, 1, 2)
# Second Largest Contour: (218, 1, 2)
# Largest Contour: (356, 1, 2)
# Second Largest Contour: (242, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (219, 1, 2)
# Largest Contour: (328, 1, 2)
# Second Largest Contour: (216, 1, 2)
# Largest Contour: (321, 1, 2)
# Second Largest Contour: (219, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (230, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (242, 1, 2)
# Largest Contour: (316, 1, 2)
# Second Largest Contour: (212, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (225, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (240, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (225, 1, 2)
# Largest Contour: (306, 1, 2)
# Second Largest Contour: (234, 1, 2)
# Largest Contour: (319, 1, 2)
# Second Largest Contour: (239, 1, 2)
# Largest Contour: (313, 1, 2)
# Second Largest Contour: (271, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (368, 1, 2)
# Largest Contour: (314, 1, 2)
# Second Largest Contour: (447, 1, 2)
# Largest Contour: (321, 1, 2)
# Second Largest Contour: (451, 1, 2)
# Largest Contour: (318, 1, 2)
# Second Largest Contour: (413, 1, 2)
# Largest Contour: (339, 1, 2)
# Second Largest Contour: (477, 1, 2)
# Largest Contour: (336, 1, 2)
# Second Largest Contour: (469, 1, 2)
# Largest Contour: (338, 1, 2)
# Second Largest Contour: (472, 1, 2)
# Largest Contour: (348, 1, 2)
# Second Largest Contour: (459, 1, 2)
# Largest Contour: (339, 1, 2)
# Second Largest Contour: (437, 1, 2)
# Largest Contour: (312, 1, 2)
# Second Largest Contour: (439, 1, 2)
# Largest Contour: (322, 1, 2)
# Second Largest Contour: (425, 1, 2)
# Largest Contour: (334, 1, 2)
# Second Largest Contour: (433, 1, 2)
# Largest Contour: (333, 1, 2)
# Second Largest Contour: (443, 1, 2)
# Largest Contour: (327, 1, 2)
# Second Largest Contour: (418, 1, 2)
# Largest Contour: (305, 1, 2)
# Second Largest Contour: (431, 1, 2)
# Largest Contour: (309, 1, 2)
# Second Largest Contour: (422, 1, 2)
# Largest Contour: (329, 1, 2)
# Second Largest Contour: (405, 1, 2)
# Largest Contour: (323, 1, 2)
# Second Largest Contour: (394, 1, 2)
# Largest Contour: (326, 1, 2)
# Second Largest Contour: (407, 1, 2)
# Largest Contour: (327, 1, 2)
# Second Largest Contour: (375, 1, 2)
# Largest Contour: (322, 1, 2)
# ...
# Largest Contour: (254, 1, 2)
# Second Largest Contour: (116, 1, 2)
# Largest Contour: (282, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (282, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (276, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (247, 1, 2)
# Second Largest Contour: (123, 1, 2)
# Largest Contour: (268, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (272, 1, 2)
# Second Largest Contour: (119, 1, 2)
# Largest Contour: (275, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (251, 1, 2)
# Second Largest Contour: (131, 1, 2)
# Largest Contour: (261, 1, 2)
# Second Largest Contour: (130, 1, 2)
# Largest Contour: (277, 1, 2)
# Second Largest Contour: (122, 1, 2)
# Largest Contour: (277, 1, 2)
# Second Largest Contour: (122, 1, 2)
# Largest Contour: (273, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (284, 1, 2)
# Second Largest Contour: (108, 1, 2)
# Largest Contour: (283, 1, 2)
# Second Largest Contour: (120, 1, 2)
# Largest Contour: (280, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (183, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (284, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (173, 1, 2)
# Second Largest Contour: (120, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (272, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (156, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (186, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (159, 1, 2)
# Second Largest Contour: (117, 1, 2)
# Largest Contour: (164, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (180, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (148, 1, 2)
# Second Largest Contour: (130, 1, 2)
# Largest Contour: (162, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (171, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (152, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (133, 1, 2)
# Largest Contour: (181, 1, 2)
# Second Largest Contour: (145, 1, 2)
# Largest Contour: (174, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (155, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (154, 1, 2)
# Second Largest Contour: (115, 1, 2)
# Largest Contour: (156, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (164, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (143, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (136, 1, 2)
# Second Largest Contour: (136, 1, 2)
# Largest Contour: (161, 1, 2)
# Second Largest Contour: (136, 1, 2)
# Largest Contour: (161, 1, 2)
# Second Largest Contour: (140, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (174, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (145, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (172, 1, 2)
# Second Largest Contour: (148, 1, 2)
# Largest Contour: (154, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (102, 1, 2)
# Largest Contour: (159, 1, 2)
# Second Largest Contour: (130, 1, 2)
# Largest Contour: (155, 1, 2)
# Second Largest Contour: (117, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (121, 1, 2)
# Largest Contour: (158, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (291, 1, 2)
# Second Largest Contour: (138, 1, 2)
# Largest Contour: (182, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (180, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (189, 1, 2)
# Second Largest Contour: (121, 1, 2)
# Largest Contour: (162, 1, 2)
# Second Largest Contour: (117, 1, 2)
# Largest Contour: (168, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (141, 1, 2)
# Largest Contour: (172, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (172, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (174, 1, 2)
# Second Largest Contour: (121, 1, 2)
# Largest Contour: (162, 1, 2)
# Second Largest Contour: (120, 1, 2)
# Largest Contour: (247, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (215, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (192, 1, 2)
# Second Largest Contour: (132, 1, 2)
# Largest Contour: (192, 1, 2)
# Second Largest Contour: (132, 1, 2)
# Largest Contour: (281, 1, 2)
# Second Largest Contour: (117, 1, 2)
# Largest Contour: (159, 1, 2)
# Second Largest Contour: (121, 1, 2)
# Largest Contour: (165, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (160, 1, 2)
# Second Largest Contour: (124, 1, 2)
# Largest Contour: (273, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (286, 1, 2)
# Second Largest Contour: (118, 1, 2)
# Largest Contour: (175, 1, 2)
# Second Largest Contour: (110, 1, 2)
# Largest Contour: (167, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (167, 1, 2)
# Second Largest Contour: (113, 1, 2)
# Largest Contour: (270, 1, 2)
# Second Largest Contour: (119, 1, 2)
# Largest Contour: (260, 1, 2)
# Second Largest Contour: (114, 1, 2)
# Largest Contour: (276, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (261, 1, 2)
# Second Largest Contour: (121, 1, 2)
# Largest Contour: (179, 1, 2)
# Second Largest Contour: (126, 1, 2)
# Largest Contour: (263, 1, 2)
# Second Largest Contour: (138, 1, 2)
# Largest Contour: (172, 1, 2)
# Second Largest Contour: (114, 1, 2)
# Largest Contour: (192, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (192, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (276, 1, 2)
# Second Largest Contour: (133, 1, 2)
# Largest Contour: (285, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (212, 1, 2)
# Second Largest Contour: (134, 1, 2)
# Largest Contour: (190, 1, 2)
# Second Largest Contour: (158, 1, 2)
# Largest Contour: (179, 1, 2)
# Second Largest Contour: (282, 1, 2)
# Largest Contour: (332, 1, 2)
# Second Largest Contour: (439, 1, 2)
# Largest Contour: (215, 1, 2)
# Second Largest Contour: (518, 1, 2)
# Largest Contour: (503, 1, 2)
# Second Largest Contour: (252, 1, 2)
# Largest Contour: (590, 1, 2)
# Second Largest Contour: (219, 1, 2)
# Largest Contour: (226, 1, 2)
# Second Largest Contour: (415, 1, 2)
# Largest Contour: (412, 1, 2)
# Second Largest Contour: (393, 1, 2)
# Largest Contour: (269, 1, 2)
# Second Largest Contour: (280, 1, 2)
# Largest Contour: (285, 1, 2)
# Second Largest Contour: (300, 1, 2)
# Largest Contour: (404, 1, 2)
# Second Largest Contour: (290, 1, 2)
# Largest Contour: (256, 1, 2)
# Second Largest Contour: (289, 1, 2)
# Largest Contour: (378, 1, 2)
# Second Largest Contour: (258, 1, 2)
# Largest Contour: (275, 1, 2)
# Second Largest Contour: (268, 1, 2)
# Largest Contour: (516, 1, 2)
# Second Largest Contour: (184, 1, 2)
# Largest Contour: (376, 1, 2)
# Second Largest Contour: (589, 1, 2)
# Largest Contour: (581, 1, 2)
# Second Largest Contour: (315, 1, 2)
# Largest Contour: (426, 1, 2)
# Second Largest Contour: (609, 1, 2)
# Largest Contour: (293, 1, 2)
# Second Largest Contour: (463, 1, 2)
# Largest Contour: (273, 1, 2)
# Second Largest Contour: (313, 1, 2)
# Largest Contour: (284, 1, 2)
# Second Largest Contour: (367, 1, 2)
# Largest Contour: (255, 1, 2)
# Second Largest Contour: (331, 1, 2)
# Largest Contour: (273, 1, 2)
# Second Largest Contour: (206, 1, 2)
# Largest Contour: (276, 1, 2)
# Second Largest Contour: (183, 1, 2)
# Largest Contour: (276, 1, 2)
# Second Largest Contour: (179, 1, 2)
# Largest Contour: (390, 1, 2)
# Second Largest Contour: (179, 1, 2)
# Largest Contour: (267, 1, 2)
# Second Largest Contour: (187, 1, 2)
# Largest Contour: (390, 1, 2)
# Second Largest Contour: (186, 1, 2)
# Largest Contour: (255, 1, 2)
# Second Largest Contour: (180, 1, 2)
# Largest Contour: (285, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (370, 1, 2)
# Second Largest Contour: (353, 1, 2)
# Largest Contour: (429, 1, 2)
# Second Largest Contour: (206, 1, 2)
# Largest Contour: (367, 1, 2)
# Second Largest Contour: (177, 1, 2)
# Largest Contour: (292, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (379, 1, 2)
# Second Largest Contour: (179, 1, 2)
# Largest Contour: (361, 1, 2)
# Second Largest Contour: (188, 1, 2)
# Largest Contour: (219, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (320, 1, 2)
# Second Largest Contour: (166, 1, 2)
# Largest Contour: (293, 1, 2)
# Second Largest Contour: (163, 1, 2)
# Largest Contour: (393, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (190, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (169, 1, 2)
# Second Largest Contour: (125, 1, 2)
# Largest Contour: (189, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (305, 1, 2)
# Second Largest Contour: (142, 1, 2)
# Largest Contour: (198, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (307, 1, 2)
# Second Largest Contour: (123, 1, 2)
# Largest Contour: (165, 1, 2)
# Second Largest Contour: (123, 1, 2)
# Largest Contour: (197, 1, 2)
# Second Largest Contour: (128, 1, 2)
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (291, 1, 2)
# Second Largest Contour: (131, 1, 2)
# Largest Contour: (291, 1, 2)
# Second Largest Contour: (131, 1, 2)
# Largest Contour: (295, 1, 2)
# Second Largest Contour: (147, 1, 2)
# Largest Contour: (186, 1, 2)
# Second Largest Contour: (136, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (154, 1, 2)
# Largest Contour: (268, 1, 2)
# Second Largest Contour: (157, 1, 2)
# Largest Contour: (153, 1, 2)
# Second Largest Contour: (149, 1, 2)
# Largest Contour: (153, 1, 2)
# Second Largest Contour: (145, 1, 2)
# Largest Contour: (159, 1, 2)
# Second Largest Contour: (133, 1, 2)
# Largest Contour: (190, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (190, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (171, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (166, 1, 2)
# Second Largest Contour: (142, 1, 2)
# Largest Contour: (169, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (164, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (171, 1, 2)
# Second Largest Contour: (159, 1, 2)
# Largest Contour: (149, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (159, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (159, 1, 2)
# Largest Contour: (148, 1, 2)
# Second Largest Contour: (141, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (163, 1, 2)
# Largest Contour: (181, 1, 2)
# Second Largest Contour: (157, 1, 2)
# Largest Contour: (171, 1, 2)
# Second Largest Contour: (157, 1, 2)
# Largest Contour: (158, 1, 2)
# Second Largest Contour: (156, 1, 2)
# Largest Contour: (175, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (154, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (154, 1, 2)
# Largest Contour: (164, 1, 2)
# Second Largest Contour: (151, 1, 2)
# Largest Contour: (181, 1, 2)
# Second Largest Contour: (145, 1, 2)
# Largest Contour: (175, 1, 2)
# Second Largest Contour: (164, 1, 2)
# Largest Contour: (178, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (168, 1, 2)
# Second Largest Contour: (157, 1, 2)
# Largest Contour: (168, 1, 2)
# Second Largest Contour: (156, 1, 2)
# Largest Contour: (160, 1, 2)
# Second Largest Contour: (138, 1, 2)
# Largest Contour: (158, 1, 2)
# Second Largest Contour: (162, 1, 2)
# Largest Contour: (167, 1, 2)
# Second Largest Contour: (165, 1, 2)
# Largest Contour: (171, 1, 2)
# Second Largest Contour: (165, 1, 2)
# Largest Contour: (188, 1, 2)
# Second Largest Contour: (161, 1, 2)
# Largest Contour: (184, 1, 2)
# Second Largest Contour: (174, 1, 2)
# Largest Contour: (179, 1, 2)
# Second Largest Contour: (161, 1, 2)
# Largest Contour: (181, 1, 2)
# Second Largest Contour: (165, 1, 2)
# Largest Contour: (177, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (187, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (173, 1, 2)
# Second Largest Contour: (178, 1, 2)
# Largest Contour: (165, 1, 2)
# Second Largest Contour: (149, 1, 2)
# Largest Contour: (153, 1, 2)
# Second Largest Contour: (151, 1, 2)
# Largest Contour: (164, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (127, 1, 2)
# Largest Contour: (150, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (134, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (145, 1, 2)
# Largest Contour: (162, 1, 2)
# Second Largest Contour: (160, 1, 2)
# Largest Contour: (144, 1, 2)
# Second Largest Contour: (152, 1, 2)
# Largest Contour: (167, 1, 2)
# Second Largest Contour: (168, 1, 2)
# Largest Contour: (152, 1, 2)
# Second Largest Contour: (148, 1, 2)
# Largest Contour: (147, 1, 2)
# Second Largest Contour: (148, 1, 2)
# Largest Contour: (173, 1, 2)
# Second Largest Contour: (152, 1, 2)
# Largest Contour: (151, 1, 2)
# Second Largest Contour: (135, 1, 2)
# Largest Contour: (257, 1, 2)
# Second Largest Contour: (155, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (146, 1, 2)
# Largest Contour: (153, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (168, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (143, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (249, 1, 2)
# Second Largest Contour: (165, 1, 2)
# Largest Contour: (260, 1, 2)
# Second Largest Contour: (140, 1, 2)
# Largest Contour: (257, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (248, 1, 2)
# Second Largest Contour: (179, 1, 2)
# Largest Contour: (231, 1, 2)
# Second Largest Contour: (183, 1, 2)
# Largest Contour: (230, 1, 2)
# Second Largest Contour: (158, 1, 2)
# Largest Contour: (259, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (251, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (252, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (267, 1, 2)
# Second Largest Contour: (137, 1, 2)
# Largest Contour: (155, 1, 2)
# Second Largest Contour: (134, 1, 2)
# Largest Contour: (170, 1, 2)
# Second Largest Contour: (129, 1, 2)
# Largest Contour: (283, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (154, 1, 2)
# Second Largest Contour: (149, 1, 2)
# Largest Contour: (146, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (149, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (157, 1, 2)
# Second Largest Contour: (143, 1, 2)
# Largest Contour: (165, 1, 2)
# Second Largest Contour: (150, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (163, 1, 2)
# Second Largest Contour: (153, 1, 2)
# Largest Contour: (177, 1, 2)
# Second Largest Contour: (142, 1, 2)
# Largest Contour: (153, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (156, 1, 2)
# Second Largest Contour: (139, 1, 2)
# Largest Contour: (156, 1, 2)
# Second Largest Contour: (133, 1, 2)
# Largest Contour: (136, 1, 2)
# Second Largest Contour: (144, 1, 2)
# Largest Contour: (147, 1, 2)
# Second Largest Contour: (132, 1, 2)
# Largest Contour: (139, 1, 2)
# Second Largest Contour: (142, 1, 2)
# Largest Contour: (146, 1, 2)
# Second Largest Contour: (140, 1, 2)
# Largest Contour: (243, 1, 2)
# Second Largest Contour: (148, 1, 2)
# Largest Contour: (243, 1, 2)
# Second Largest Contour: (148, 1, 2)
# Largest Contour: (365, 1, 2)
# Second Largest Contour: (110, 1, 2)
# Largest Contour: (357, 1, 2)
# Second Largest Contour: (112, 1, 2)
